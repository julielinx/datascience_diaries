# %% [markdown]
# # Entry 15 notebook - Categorical Correlation/Collinearity - Nursery Dataset
#
# Categorical collinearity using the [Nursery Dataset](http://archive.ics.uci.edu/ml/datasets/Nursery) on the UCI Repository.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')

import category_encoders as ce
import scipy.stats as ss
import math
from collections import Counter

# %% [markdown]
# ### Functions

# %%
def drop_undifferentiated(df):
    drop_cols = []
    for col in df.columns:
        if len(df[col].unique()) == 1:
            drop_cols.append(col)
    df = df.drop(drop_cols, axis=1)
    return df

# %%
def p_and_s_corrs(df, target, encoder=ce.OrdinalEncoder):
    cat_cols = df.columns.tolist()
    index = df.index.tolist()
    encoder = encoder(cols=cat_cols)
    encd_df = pd.DataFrame(encoder.fit_transform(df[cat_cols], target), index=index)
    encd_df = drop_undifferentiated(encd_df)
    
    pearson = encd_df.corr()
    spearman = encd_df.corr(method='spearman')
    return pearson, spearman

def viz_double_heatmap(df1, name1, df2, name2, vmin=-1, vmax=1, annot=False):
    plt.figure(figsize=(20,7))
    plt.subplot(1, 2, 1)
    sns.heatmap(df1, vmin=vmin, vmax=vmax, annot=annot)
    plt.title(name1 + ' correlations')
    
    plt.subplot(1, 2, 2)
    sns.heatmap(df2, vmin=vmin, vmax=vmax, annot=annot)
    plt.title(name2 + ' correlations')
    
    plt.show()

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

def cramers_df(df):
    cramers = pd.DataFrame()
    for i, a in enumerate(df.columns):
        cramers.loc[a, a] = 1.0
        for b in df.columns[:i]:
            val = round(cramers_v(df[a], df[b]), 2)
            cramers.loc[a,b] = val
            cramers.loc[b,a] = val
    return cramers

# %%
def conditional_entropy(x, y):
    y_counter = Counter(y)
    xy_counter = Counter(list(zip(x, y)))
    total_occurrences = sum(y_counter.values())
    entropy = 0.0
    for xy in xy_counter.keys():
        p_xy = xy_counter[xy] / total_occurrences
        p_y = y_counter[xy[1]] / total_occurrences
        entropy += p_xy * math.log(p_y / p_xy)
    return entropy

def theils_u(x, y):
    s_xy = conditional_entropy(x,y)
    x_counter = Counter(x)
    total_occurrences = sum(x_counter.values())
    p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
    s_x = ss.entropy(p_x)
    if s_x == 0:
        return 1
    else:
        return (s_x - s_xy) / s_x
    
def theils_df(df):
    theil = pd.DataFrame()
    for i, a in enumerate(df.columns):
        theil.loc[a, a] = 1.0
        for b in df.columns:
            theil.loc[a,b] = round(theils_u(df[b], df[a]), 2)
            theil.loc[b,a] = round(theils_u(df[a], df[b]), 2)
    return theil

# %% [markdown]
# ### Data

# %%
col_names = ['parents', 'has_nurs', 'form', 'children', 'housing', 'finance', 'social', 'health', 'class']

df_raw = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/nursery/nursery.data',
                     header=None, names=col_names)
df_raw.head()
# Out:
#   parents has_nurs      form children     housing     finance         social  \
# 0   usual   proper  complete        1  convenient  convenient        nonprob
# 1   usual   proper  complete        1  convenient  convenient        nonprob
# 2   usual   proper  complete        1  convenient  convenient        nonprob
# 3   usual   proper  complete        1  convenient  convenient  slightly_prob
# 4   usual   proper  complete        1  convenient  convenient  slightly_prob
#
#         health      class
# 0  recommended  recommend
# 1     priority   priority
# 2    not_recom  not_recom
# 3  recommended  recommend
# 4     priority   priority

# %%
target = 'class'
        
df_y = df_raw[target].astype('category').cat.codes
df = df_raw.drop(target, axis=1)
df = drop_undifferentiated(df)
df.tail()
# Out:
#           parents   has_nurs    form children   housing finance  \
# 12955  great_pret  very_crit  foster     more  critical  inconv
# 12956  great_pret  very_crit  foster     more  critical  inconv
# 12957  great_pret  very_crit  foster     more  critical  inconv
# 12958  great_pret  very_crit  foster     more  critical  inconv
# 12959  great_pret  very_crit  foster     more  critical  inconv
#
#               social       health
# 12955  slightly_prob     priority
# 12956  slightly_prob    not_recom
# 12957    problematic  recommended
# 12958    problematic     priority
# 12959    problematic    not_recom

# %% [markdown]
# ### Pearson and Spearman correlations with encoding

# %%
target_indepnt = [ce.OrdinalEncoder, ce.OneHotEncoder, ce.BinaryEncoder, ce.HashingEncoder,
                  ce.BackwardDifferenceEncoder, ce.HelmertEncoder, ce.PolynomialEncoder, ce.SumEncoder]
target_depnt = [ce.CatBoostEncoder, ce.JamesSteinEncoder, ce.LeaveOneOutEncoder,
                ce.MEstimateEncoder, ce.TargetEncoder, ce.WOEEncoder]

# %%
for encoder in target_indepnt:
    print(str(encoder))
    pearson, spearman = p_and_s_corrs(df, df_y, encoder=encoder)
    viz_double_heatmap(pearson, 'pearson', spearman, 'spearman')
    print('\n')
# Out:
# <class 'category_encoders.ordinal.OrdinalEncoder'>
# <class 'category_encoders.one_hot.OneHotEncoder'>
# <class 'category_encoders.binary.BinaryEncoder'>
# <class 'category_encoders.hashing.HashingEncoder'>
# <class 'category_encoders.backward_difference.BackwardDifferenceEncoder'>
# <class 'category_encoders.helmert.HelmertEncoder'>
# <class 'category_encoders.polynomial.PolynomialEncoder'>
# <class 'category_encoders.sum_coding.SumEncoder'>

# %%
for encoder in target_depnt:
    print(str(encoder))
    pearson, spearman = p_and_s_corrs(df, df_y, encoder=encoder)
    viz_double_heatmap(pearson, 'pearson', spearman, 'spearman')
    print('\n')
# Out:
# <class 'category_encoders.cat_boost.CatBoostEncoder'>
# <class 'category_encoders.james_stein.JamesSteinEncoder'>
# <class 'category_encoders.leave_one_out.LeaveOneOutEncoder'>
# <class 'category_encoders.m_estimate.MEstimateEncoder'>
# <class 'category_encoders.target_encoder.TargetEncoder'>
# <class 'category_encoders.woe.WOEEncoder'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-831795e707f6> in <module>
#       1 for encoder in target_depnt:
#       2     print(str(encoder))
# ----> 3     pearson, spearman = p_and_s_corrs(df, df_y, encoder=encoder)
#       4     viz_double_heatmap(pearson, 'pearson', spearman, 'spearman')
#       5     print('\n')
#
# <ipython-input-18-966a60e6aa31> in p_and_s_corrs(df, target, encoder)
#       3     index = df.index.tolist()
#       4     encoder = encoder(cols=cat_cols)
# ----> 5     encd_df = pd.DataFrame(encoder.fit_transform(df[cat_cols], target), index=index)
#       6     encd_df = drop_undifferentiated(encd_df)
#       7
#
# //anaconda3/lib/python3.7/site-packages/category_encoders/woe.py in fit_transform(self, X, y, **fit_params)
#     252             raise(TypeError, 'fit_transform() missing argument: ''y''')
#     253
# --> 254         return self.fit(X, y, **fit_params).transform(X, y)
#     255
#     256     def _train(self, X, y):
#
# //anaconda3/lib/python3.7/site-packages/category_encoders/woe.py in fit(self, X, y, **kwargs)
#     127         unique = y.unique()
#     128         if len(unique) != 2:
# --> 129             raise ValueError("The target column y must be binary. But the target contains " + str(len(unique)) + " unique value(s).")
#     130         if y.isnull().any():
#     131             raise ValueError("The target column y must not contain missing values.")
#
# ValueError: The target column y must be binary. But the target contains 5 unique value(s).

# %% [markdown]
# ### Cramer's V and Theil's U

# %%
cramers = cramers_df(df)
theils = theils_df(df)
viz_double_heatmap(cramers, "Cramer's V", theils, "Theil's U", vmin=0, annot=True)
