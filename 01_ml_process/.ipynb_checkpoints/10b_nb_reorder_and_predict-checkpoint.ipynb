# %% [markdown]
# # Entry 10 notebook - Reorder Pre-processing and Make Prediction - Atmospheric Mass

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import category_encoders as ce

# %% [markdown]
# ### Custom functions

# %%
def feature_corr_coll(df, target, corr_type='spearman'):
    target_corr = pd.DataFrame(df.corrwith(target, axis=0, method=corr_type).reset_index()).rename(columns={0:corr_type})
    target_corr['abs'] = target_corr[corr_type].abs()
    top_features = target_corr[target_corr['abs'] >= 0.5].sort_values('abs', ascending=False)['index'].tolist()
    df_top = df[top_features]
    feature_corr = df_top.corr(method=corr_type)
    
    collinear_features = set()
    for i in range(len(feature_corr.columns)):
        sliced_matrix = feature_corr.iloc[i, :i]
        if sum(sliced_matrix[abs(sliced_matrix) > 0.9]):
            colname = feature_corr.columns[i]
            collinear_features.add(colname)
    collinear_features = list(collinear_features)
    df = df_top.drop(collinear_features, axis=1)
    
    select_features = df.columns.tolist()
    
    return select_features, df

# %%
def preprocess_data(train_df, test_df, select_features, scaler=StandardScaler(), encoder=ce.OrdinalEncoder):
    index = train_df.index.tolist()
    test_index = test_df.index.tolist()
    
    num_features = train_df.select_dtypes('number').columns.tolist()    
    num_scale = scaler.fit_transform(train_df[num_features])
    train_num_df = pd.DataFrame(num_scale, columns=num_features, index=index)
    
    test_num_scale = scaler.transform(test_df[num_features])
    test_num_df = pd.DataFrame(test_num_scale, columns=num_features, index=test_index)
    
    cat_features = train_df.select_dtypes('object').columns.tolist()
    cat_encoder = encoder(cols=cat_features)
    cat_encode = cat_encoder.fit_transform(train_df[cat_features])
    train_cat_df = pd.DataFrame(cat_encode, columns=cat_features, index=index)
    
    test_cat_encode = cat_encoder.transform(test_df[cat_features])
    test_cat_df = pd.DataFrame(test_cat_encode, columns=cat_features, index=test_index)
    
    train_df = pd.concat([train_num_df, train_cat_df], axis=1).fillna(-1)
    test_df = pd.concat([test_num_df, test_cat_df], axis=1).fillna(-1)
    
    return train_df, test_df

# %% [markdown]
# ### Get and 'split' data
#
# The 'split' portion is currently a cheating version where I just create two new rows because I decided not to split it into train and test sets for this tiny dataset. But I want a placeholder so I don't forget to incorporate it in the next iteration when I start using bigger datasets.

# %%
planets = pd.read_excel('../data/planets_moons.xlsx', index_col=0)
# planets

# %%
# Creating the 'test' set that I'll be using to make a prediction

X_test = planets.loc[['Mars'], :].drop('atmospheric_mass_kg', axis=1)
X_test = pd.concat([X_test]*2)
X_test.index = ['Mars_low', 'Mars_high']
# Low end surface pressure based on conditions on Mt Everest
X_test.loc['Mars_low', 'surface_pressure_bars'] = 0.47
# High end surface pressure based on nigrogen narcosis experienced by divers
X_test.loc['Mars_high', 'surface_pressure_bars'] = 4
X_test
# Out:
#              type  mass_1024kg  diameter_km  density_kg_m3  gravity_m_s2  \
# Mars_low   planet        0.642       6792.0           3933           3.7
# Mars_high  planet        0.642       6792.0           3933           3.7
#
#            escape_vel_km_s  rotation_period_hr  day_len_hr  \
# Mars_low               5.0                24.6        24.7
# Mars_high              5.0                24.6        24.7
#
#            distance_from_sun_106_km  perihelion_106 km  ...  \
# Mars_low                      227.9              206.6  ...
# Mars_high                     227.9              206.6  ...
#
#            obliquity_to_orbit_degrees  mean_temp_c  surface_pressure_bars  \
# Mars_low                         25.2          -65                   0.47
# Mars_high                        25.2          -65                   4.00
#
#            nbr_moons  rings  magnetic_field  equatorial_radius_km  \
# Mars_low           2     No              No               3396.19
# Mars_high          2     No              No               3396.19
#
#            mean_radius_km  V(1,0) (mag) geometric_albedo
# Mars_low           3389.5         -1.52             0.15
# Mars_high          3389.5         -1.52             0.15
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Separate the target value

# %%
X_train = planets.drop('atmospheric_mass_kg', axis=1)
y_train = planets['atmospheric_mass_kg']

# %% [markdown]
# ### Determine collinearity and narrow features

# %%
select_features, non_coll = feature_corr_coll(X_train, y_train)
non_coll
# Out:
#          diameter_km  day_len_hr  V(1,0) (mag)  surface_pressure_bars  \
# name
# Mercury       4879.0      4222.6         -0.60           1.000000e-14
# Venus        12104.0      2802.0         -4.47           9.200000e+01
# Earth        12756.0        24.0         -3.86           1.014000e+00
# Moon          3475.0       708.7         -0.08           3.000000e-15
# Mars          6792.0        24.7         -1.52           1.000000e-02
# Jupiter     142984.0         9.9         -9.40           2.000000e+00
# Saturn      120536.0        10.7         -8.88           1.000000e+03
# Titan         5149.4       382.0         -8.10           1.600000e+00
# Uranus       51118.0        17.2         -7.19           1.000000e+03
# Neptune      49528.0        16.1         -6.87           1.000000e+03
# Pluto         2370.0       153.3         -1.00           1.000000e-05
#
#          geometric_albedo  density_kg_m3  orbital_inclination_degrees  \
# name
# Mercury             0.106           5427                          7.0
# Venus               0.650           5243                          3.4
# Earth               0.367           5514                          0.0
# Moon                0.120           3340                          5.1
# Mars                0.150           3933                          1.9
# Jupiter             0.520           1326                          1.3
# Saturn              0.470            687                          2.5
# Titan               0.210           1882                          0.3
# Uranus              0.510           1271                          0.8
# Neptune             0.410           1638                          1.8
# Pluto               0.300           2095                         17.2
#
#          rotation_period_hr
# name
# Mercury              1407.6
# Venus               -5832.5
# Earth                  23.9
# Moon                  655.7
# Mars                   24.6
# Jupiter                 9.9
# Saturn                 10.7
# Titan                 382.0
# Uranus                -17.2
# Neptune                16.1
# Pluto                -153.3

# %% [markdown]
# ### Preprocess train and test

# %%
planets_stdz, test_stdz = preprocess_data(non_coll, X_test, select_features)
planets_stdz
# Out:
#          diameter_km  day_len_hr  V(1,0) (mag)  surface_pressure_bars  \
# Mercury    -0.681977    2.568170      1.224812              -0.638729
# Venus      -0.530590    1.514217      0.075589              -0.429988
# Earth      -0.516928   -0.546799      0.256733              -0.636428
# Moon       -0.711396   -0.038815      1.379230              -0.638729
# Mars       -0.641894   -0.546279      0.951612              -0.638706
# Jupiter     2.211778   -0.557259     -1.388408              -0.634191
# Saturn      1.741418   -0.556666     -1.233991               1.630200
# Titan      -0.676311   -0.281196     -1.002364              -0.635099
# Uranus      0.286882   -0.551843     -0.732134               1.630200
# Neptune     0.253567   -0.552660     -0.637107               1.630200
# Pluto      -0.734549   -0.450870      1.106029              -0.638729
#
#          geometric_albedo  density_kg_m3  orbital_inclination_degrees  \
# Mercury         -1.374401       1.429504                     0.690697
# Venus            1.732669       1.323681                    -0.075454
# Earth            0.116307       1.479540                    -0.799041
# Moon            -1.294440       0.229214                     0.286339
# Mars            -1.123094       0.570264                    -0.394684
# Jupiter          0.990171      -0.929091                    -0.522376
# Saturn           0.704595      -1.296597                    -0.266992
# Titan           -0.780402      -0.609321                    -0.735195
# Uranus           0.933056      -0.960723                    -0.628786
# Neptune          0.361903      -0.749652                    -0.415966
# Pluto           -0.266365      -0.486819                     2.861458
#
#          rotation_period_hr
# Mercury            0.959204
# Venus             -3.070742
# Earth              0.189016
# Moon               0.540685
# Mars               0.189406
# Jupiter            0.181224
# Saturn             0.181669
# Titan              0.388340
# Uranus             0.166139
# Neptune            0.184675
# Pluto              0.090384

# %%
test_stdz
# Out:
#            diameter_km  day_len_hr  V(1,0) (mag)  surface_pressure_bars  \
# Mars_low     -0.641894   -0.546279      0.951612              -0.637663
# Mars_high    -0.641894   -0.546279      0.951612              -0.629653
#
#            geometric_albedo  density_kg_m3  orbital_inclination_degrees  \
# Mars_low          -1.123094       0.570264                    -0.394684
# Mars_high         -1.123094       0.570264                    -0.394684
#
#            rotation_period_hr
# Mars_low             0.189406
# Mars_high            0.189406

# %%
y_train
# Out:
# name
# Mercury    1.000000e+03
# Venus      4.800000e+20
# Earth      1.400000e+21
# Moon       1.000000e+05
# Mars       2.500000e+16
# Jupiter    1.900000e+27
# Saturn     5.400000e+26
# Titan      9.100000e+18
# Uranus     8.600000e+25
# Neptune    1.000000e+26
# Pluto      1.300000e+14
# Name: atmospheric_mass_kg, dtype: float64

# %% [markdown]
# ## Train model

# %%
model = LinearRegression()
model.fit(planets_stdz, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([ 4.65129803e+26,  1.04857854e+26,  2.15501708e+26, -4.09378543e+26,
#         3.04332425e+26, -2.64312434e+26, -1.45384152e+26,  1.71555552e+26])

# %%
model.score(planets_stdz, y_train)
# Out:
# 0.9748029733394393

# %% [markdown]
# ## Make Predictions

# %%
mass_pred = model.predict(test_stdz)
mass_pred
# Out:
# array([-5.36462064e+25, -5.69250491e+25])
