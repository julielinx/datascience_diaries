# %% [markdown]
# ## Resources
#
# - [The Matplotlib Line Plot that Crushes the Box Plot](https://towardsdatascience.com/the-matplotlib-line-plot-that-crushes-the-box-plot-912f8d2acd49)
# - [From Data to Viz](https://www.data-to-viz.com/)
# - [Data Visualization Society](https://www.datavisualizationsociety.com/challenge)
# - [Makeover Monday](https://www.makeovermonday.co.uk/)
# - [Seaborn](https://seaborn.pydata.org/tutorial.html)
# - [Bokeh](https://docs.bokeh.org/en/latest/index.html)
# - [Matplotlib](https://matplotlib.org/contents.html)
# - [Plotly](https://plot.ly/python/)

# %% [markdown]
# ## Datasets
#
# - [Entry 34a notebook - Regression datasets](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/34a_nb_regression_datasets.ipynb)
# - [Entry 34b notebook - Classification datasets](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/34b_nb_classification_datasets.ipynb)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
x_vals = np.linspace(-10,10,num=101)
vals = []
for x in x_vals:
    ans = -9*x**5 + 82*x**3 + 12*x**2
#     print(x, ans)
    vals.append(ans)

# %%
plt.plot(x_vals, vals)
plt.grid()
plt.axvline()
plt.axhline()
plt.show()

# %% [markdown]
# ## Examples
#
# - [Entry 5: Explore the Data](https://github.com/julielinx/julielinx.github.io/blob/master/_posts/2020-03-19-05_EDA.md)
#   - Resource list
# - [Entry 5 notebook](https://github.com/julielinx/datascience_diaries/blob/master/01_ml_process/05_nb_EDA_viz.ipynb)
#   - Seaborn
#     - pairplot
#     - relplot
#     - lmplot
#     - log scale
#     - supplot lmplots
#     - jointplot
# - [Entry 6: Correlations](https://github.com/julielinx/julielinx.github.io/blob/master/_posts/2020-03-20-06_correlation.md)
#   - Seaborn
#     - relplot
#     - lmplot
# - [Entry 7 notebook: Collinearity notebook](https://github.com/julielinx/datascience_diaries/blob/master/01_ml_process/07_nb_collinearity.ipynb)
#   - Seaborn
#     - heatmap
#     - subplot heatmaps
#     - clustermap
# - [Entry 12 notebook: Missing Values](https://github.com/julielinx/datascience_diaries/blob/master/01_ml_process/12_nb_missing_values.ipynb)
#   - missingno
#     - matrix
#     - bar
#     - heatmap
#     - dendrogram
#   - Seaborn
#     - lmplot
#     - distplot
# - [Entry 15a notebook: Categorical Correlation/Collinearity - Mushroom Dataset](https://github.com/julielinx/datascience_diaries/blob/master/01_ml_process/15a_nb_cat_corr.ipynb)
#   - Seaborn
#     - subplot heatmaps in function
# - [Entry 15b notebook: Categorical Correlation/Collinearity - Solar Flare Dataset](https://github.com/julielinx/datascience_diaries/blob/master/01_ml_process/15b_nb_cat_corr.ipynb)
#   - Seaborn
#     - subplot heatmaps in function
# - [Entry 15c notebook: Categorical Correlation/Collinearity - Nursery Dataset](https://github.com/julielinx/datascience_diaries/blob/master/01_ml_process/15c_nb_cat_corr.ipynb)
#   - Seaborn
#     - subplot heatmaps in function
# - [Entry 15d notebook: Categorical Correlation/Collinearity - Chess Dataset](https://github.com/julielinx/datascience_diaries/blob/master/01_ml_process/15d_nb_cat_corr.ipynb)
#   - Seaborn
#     - subplot heatmaps in function
# - [Entry 23: Scoring Classification Models - Theory](https://github.com/julielinx/julielinx.github.io/blob/master/_posts/2020-04-27-23_class_score_theory.md)
#   - matplotlib.pyplot
#     - multi-line line plot
#     - precision vs recall
#     - roc/auc
# - [Entry 26a notebook: Setting thresholds - PR and ROC - sklearn Breast Cancer](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/26a_nb_thresholds_pr_roc.ipynb)
#   - matplotlib.pyplot
#     - multi-line line plot
#     - precision vs recall
#     - roc/auc
# - [Entry 26b notebook: Setting thresholds - PR and ROC - openml.org Breast Cancer](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/26b_nb_thresholds_pr_roc.ipynb)
#   - matplotlib.pyplot
#     - multi-line line plot
#     - precision vs recall
#     - roc/auc
# - [Entry 26c notebook: Setting thresholds - PR and ROC - Titanic](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/26c_nb_thresholds_pr_roc.ipynb)
#   - matplotlib.pyplot
#     - multi-line line plot
#     - precision vs recall
#     - roc/auc
# - [Entry 26d notebook: Setting thresholds - PR and ROC - Horse colic](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/26d_nb_thresholds_pr_roc.ipynb)
#   - matplotlib.pyplot
#     - multi-line line plot
#     - precision vs recall
#     - roc/auc
# - [Entry 26e notebook: Setting thresholds - PR and ROC - MNIST](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/26e_nb_thresholds_pr_roc.ipynb)
#   - matplotlib.pyplot
#     - multi-line line plot
#     - precision vs recall
#     - roc/auc
# - [Entry 28a notebook: Cumulative gains and lift - Titanic](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/28a_nb_gain_lift.ipynb)
#   - skplt.metrics
#     - plot_cumulative_gain
#     - plot_lift_curve
#     - plot_ks_statistic
# - [Entry 28b notebook: Cumulative gains and lift - MNIST](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/28b_nb_gain_lift.ipynb)
#   - skplt.metrics
#     - plot_cumulative_gain
#     - plot_lift_curve
#     - plot_ks_statistic
# - [Entry 28c notebook: Cumulative gains and lift - Click prediction](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/28c_nb_gain_lift.ipynb)
#   - skplt.metrics
#     - plot_cumulative_gain
#     - plot_lift_curve
#     - plot_ks_statistic
# - [Entry 29b notebook: Thresholds - Profit and cost](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/29b_nb_thresholds_profit_cost_plots.ipynb)
#   - matplotlib.pyplot
#     - line chart
#   - pandas plot
#     - line chart
# - [Entry 30: Improve Performance - Learning Curves](https://github.com/julielinx/julielinx.github.io/blob/master/_posts/2020-06-30-30_learning_curves_imp_perform.md)
#   - matplot.pyplot
#     - line chart with annotation
#     - scatter plot
# - [Entry 30 notebook: Learning Curves](https://github.com/julielinx/datascience_diaries/blob/master/02_model_eval/30_nb_learning_curves.ipynb)
#   - matplotlib.pyplot
#     - multi-line line plot / learning curves
#     - scatter plot
# - [Entry 32 notebook: Modeling data](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/32_nb_model_algos.ipynb)
#   - matplotlib.pyplot
#     - scatter plot
# - [Entry 34a notebook: Regression datasets](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/34a_nb_regression_datasets.ipynb)
#   - Seaborn
#     - subplotted lmplots
#     - pairplot
#     - subsetted swarmplot
#     - scatterplot
#     - FacetGrid
# - [Entry 34b notebook: Classification datasets](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/34b_nb_classification_datasets.ipynb)
#   - Seaborn
#     - lmplot
#     - pairplot
# - [Entry 35: Regression](https://github.com/julielinx/julielinx.github.io/blob/master/_posts/2020-08-06-35_regression.md)
#   - Seaborn
#     - lmplot
# - [Entry 35a notebook: Regression](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/01_regression/35a_nb_regression.ipynb)
#   - Seaborn
#     - scatterplot
#     - regplot
# - [Entry 35b notebook: Regression](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/01_regression/35b_nb_regression.ipynb)
#   - matplotlib.pyplot
#     - 3d
# - [Entry 36a notebook: Linear Regression](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/01_regression/36a_nb_regression.ipynb)
#   - matplotlib.pyplot
#     - scatter
#     - plot
#   - Seaborn
#     - pairplot
#     - scatterplot
#     - regplot
#     - lmplot
# - [Entry 37b notebook: Gradient Descent](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/01_regression/37b_regression_gradient_descent.ipynb)
#   - Seaborn
#     - lmplot
#     - scatterplot
#   - matplotlib.pyplot
#     - plot
#     - plot_trisurf
# - [Entry 42: Logistic Regression](https://github.com/julielinx/julielinx.github.io/blob/master/_posts/2020-10-01-42_regression_logistic.md)
#   - matplotlib.pyplot
#     - plot
# - [Entry 44a notebook: Decision Trees](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/02_tree_based/44a_nb_decision_trees.ipynb)
#   - Seaborn
#     - pairplot
#     - barplot
#   - sklearn.tree
#     - export_graphviz
#     - export_text
#     - plot_tree
# - [Entry 45a notebook: Visualize Decision Trees](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/02_tree_based/45a_nb_trees_viz.ipynb)
#   - sklearn.tree
#     - export_graphviz
#     - plot_tree
#   - pydotplus
# - [Entry 49a notebook: Decision Trees Analysis and Interpretation](https://github.com/julielinx/datascience_diaries/blob/master/03_supervised_learning/02_tree_based/49a_nb_trees_analysis_interpt.ipynb)
#   - Seaborn
#     - barplot
#     - distplot
#   - sklearn.tree
#     - export_graphviz
# - [Entry g10a notebook: Unimodal Model Local Metrics](https://github.com/julielinx/datascience_diaries/blob/master/graph/10a_nb_uni_local_metrics.ipynb)
#   - Seaborn
#     - distplot
# - [Entry g10b notebook: Bimodal Model Global Metrics](https://github.com/julielinx/datascience_diaries/blob/master/graph/10b_nb_bi_local_metrics.ipynb)
#   - Seaborn
#     - distplot
# - [Entry g10c notebook: Mixed Model Global Metrics](https://github.com/julielinx/datascience_diaries/blob/master/graph/10c_nb_mix_local_metrics.ipynb)
#   - Seaborn
#     - distplot
# - [Entry g12a notebook: Degree Comparison](https://github.com/julielinx/datascience_diaries/blob/master/graph/12a_nb_degree_comparison.ipynb)
#   - matplotlib.pyplot
#     - hist
#     - subplots
# - [Entry g12b notebook: Degree Comparison](https://github.com/julielinx/datascience_diaries/blob/master/graph/12b_nb_degree_comparison.ipynb)
#   - matplotlib.pyplot
#     - hist
#     - subplots
# - [Entry g12c notebook: Degree Comparison](https://github.com/julielinx/datascience_diaries/blob/master/graph/12c_nb_degree_comparison.ipynb)
#   - matplotlib.pyplot
#     - hist
#     - subplots
# - [Entry g13a notebook: Weighted Degree Comparison](https://github.com/julielinx/datascience_diaries/blob/master/graph/13a_nb_weighted_degree_comparison.ipynb)
#   - matplotlib.pyplot
#     - hist
#     - subplots
# - [Entry g19a notebook: Neighborhood Node Counts](https://github.com/julielinx/datascience_diaries/blob/master/graph/19a_nb_neighborhood_node_cts.ipynb)
#   - matplotlib.pyplot
#     - hist
#     - subplots
# - [Entry g19b notebook: Neighborhood Node Counts](https://github.com/julielinx/datascience_diaries/blob/master/graph/19b_nb_neighborhood__node_cts.ipynb)
#   - matplotlib.pyplot
#     - subplots
#   - Seaborn
#     - histplot
# - [Entry g19c notebook: Neighborhood Node Counts](https://github.com/julielinx/datascience_diaries/blob/master/graph/19c_nb_neighborhood_node_cts.ipynb)
#   - matplotlib.pyplot
#     - subplots
#   - Seaborn
#     - histplot
# - [Entry g20a notebook: Shortest Path](https://github.com/julielinx/datascience_diaries/blob/master/graph/20a_nb_shortest_path.ipynb)
#   - Seaborn
#     - histplot
# - [eval_presentation](https://github.com/julielinx/datascience_diaries/blob/master/eval_presentation.ipynb)
#   - matplotlib.pyplot
#     - plot
#       - precision vs recall
#       - roc curve
