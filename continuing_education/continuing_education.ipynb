# %% [markdown]
# # Plan
#
# - Computer Science
#     - [ ] [CSE 140/160: Introduction to data programming with applications](https://homes.cs.washington.edu/~mernst/teaching/data-programming/)
# - Calculus 1 / Single variable calculus
#     - [ ] [Highlights of Calculus - Supplement](https://ocw.mit.edu/resources/res-18-005-highlights-of-calculus-spring-2010/)
#     - [ ] [MIT 18.01 Single Variable Calculus](https://ocw.mit.edu/courses/mathematics/18-01-single-variable-calculus-fall-2006/)
#     - [ ] [Calculus Revisited: Single Variable Calculus](https://ocw.mit.edu/resources/res-18-006-calculus-revisited-single-variable-calculus-fall-2010/)
# - Discrete Mathematics / Math for Computer Science
#     - [ ] MIT 6.042J / 18.062J: [Mathematics for Computer Science](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-fall-2010/)
# - Computer Science
#     - [ ] [CSE 142: Computer Programming I](http://courses.cs.washington.edu/courses/cse142/) - Need this?
#     - [ ] [CSE 143: Computer Programming II](http://courses.cs.washington.edu/courses/cse143/)
#     - [ ] [CSE 311: Foundations of Computing I](http://courses.cs.washington.edu/courses/cse311/)
#     - [ ] [CSE 312: Foundations of Computing II](http://courses.cs.washington.edu/courses/cse312/)
# - Calculus 2 / Multivariable Calculus
#     - [ ] [MIT 18.02 Multivariable Calculus](https://ocw.mit.edu/courses/mathematics/18-02-multivariable-calculus-fall-2007/)
#     - [ ] [Calculus Revisited: Multivariable Calculus](https://ocw.mit.edu/resources/res-18-007-calculus-revisited-multivariable-calculus-fall-2011/)
# - Physics
#     - [ ] [Introduction to Electricity and Magnetism Specialization](https://www.coursera.org/specializations/introduction-to-electricity-magnetism#courses)
#     - [ ] [Introduction to Mechanics Specialization](https://www.coursera.org/specializations/introduction-to-mechanics#courses)
# - Differential Equations
#     - [ ] MIT 18.03 Differential Equations
#       - [Spring 2010](https://ocw.mit.edu/courses/mathematics/18-03-differential-equations-spring-2010/index.htm)
#       - [Fall 2011](https://ocw.mit.edu/courses/mathematics/18-03sc-differential-equations-fall-2011/)
#     - [ ] [Learn Differential Equations: Up Close with Gilbert Strang and Cleve Moler - Supplement](https://ocw.mit.edu/resources/res-18-009-learn-differential-equations-up-close-with-gilbert-strang-and-cleve-moler-fall-2015/)
#     - [ ] [Calculus Revisited: Complex Variables, Differential Equations, and Linear Algebra](https://ocw.mit.edu/resources/res-18-008-calculus-revisited-complex-variables-differential-equations-and-linear-algebra-fall-2011/)
# - Linear Algebra
#     - [ ] [MIT A 202 Vision of Linear Algebra - Supplement](https://ocw.mit.edu/resources/res-18-010-a-2020-vision-of-linear-algebra-spring-2020/)
#     - [ ] [MIT 18.06: Linear Algebra](https://ocw.mit.edu/courses/mathematics/18-06sc-linear-algebra-fall-2011/)
#     - [ ] [MIT 18.065 Matrix Methods in Data Analysis, Singal Processing, and Machine Learning](https://ocw.mit.edu/courses/mathematics/18-065-matrix-methods-in-data-analysis-signal-processing-and-machine-learning-spring-2018/)
# - Statistics
#     - [ ] [MIT 18.650 Statistics for Applications](https://ocw.mit.edu/courses/mathematics/18-650-statistics-for-applications-fall-2016/)
# - Computer Science / Machine Learning
#     - [ ] [CSE 163: Intermediate Data Programming](https://courses.cs.washington.edu/courses/cse163/)

# %% [markdown]
# # Currently working on:

# %% [markdown]
# - [University of Washington Computer Science and Engineering courses](https://www.cs.washington.edu/education/courses)
#   - [CSE 140/160: Introduction to data programming with applications](https://homes.cs.washington.edu/~mernst/teaching/data-programming/)
#     - [Think Python ebook](https://greenteapress.com/thinkpython2/thinkpython2.pdf)
#     - [Think Python github](https://github.com/AllenDowney/ThinkPython2/tree/master/code)
#     - [Python Docs](https://www.python.org/doc/)
#     - [Python Docs Standard Library](https://docs.python.org/3/library/index.html)
#     - [Python Docs Beginner’s Guide](https://wiki.python.org/moin/BeginnersGuide)
#     - [Python Docs Tutorial](https://docs.python.org/3/tutorial/index.html)
#     - [Learn Python the Hard Way ebook](https://learnpythonthehardway.org/)
#
# ### Sagemaker:
#
# - [ ] [Sagemaker Workshop](https://sagemaker-workshop.com/)
# - [ ] [Sagemaker Immersion day](https://catalog.us-east-1.prod.workshops.aws/workshops/63069e26-921c-4ce1-9cc7-dd882ff62575/en-US)
# - [ ] [Documentation](https://docs.aws.amazon.com/sagemaker/index.html)
# - [ ] [Github: Sagemaker experiments](https://github.com/aws/sagemaker-experiments)
# - [ ] [Github: Amazon Sagemaker examples](https://github.com/aws/amazon-sagemaker-examples)
# - [ ] [Github: sagemaker python sdk](https://github.com/aws/sagemaker-python-sdk)
# - [ ] [Udacity: AWS Machine Learning Engineer nanodegree](https://www.udacity.com/course/aws-machine-learning-engineer-nanodegree--nd189)
# - [ ] [Youtube: Detect ML model drift in production](https://www.youtube.com/watch?v=J9T0X9Jxl_w)
# - [ ] [Youtube: Deep Dive on Amazon Sagemaker](https://www.youtube.com/watch?v=0zqoeZxakOI)
# - [ ] [AWS newsfeed: Monitor ML models using Sagemaker model monitor](https://awscloudfeed.com/whats-new/machine-learning/monitoring-in-production-ml-models-at-large-scale-using-amazon-sagemaker-model-monitor)
# - [ ] [AWS: Sagemaker Experiments – Organize, Track and Compare ML trainings](https://aws.amazon.com/blogs/aws/amazon-sagemaker-experiments-organize-track-and-compare-your-machine-learning-trainings/)
# - [ ] [Youtube: AWS ML playlist](https://www.youtube.com/playlist?list=PL5bUlblGfe0Ljo83LHtrRPXdQAsklFEFB)
#
# ### ACloudGuru.com:
#
# - [ ] [Containers Learning Track](https://learn.acloud.guru/learning-path/cloud-adjacent-containers)
# - [ ] [DevOps Learning Track](https://learn.acloud.guru/learning-path/cloud-adjacent-devops)
#
# ### More
#
#   - [NLP - spell correct/similarity](http://norvig.com/spell-correct.html)
#   - [eScience Institute – Data Science courses at UW](https://escience.washington.edu/data-science-courses-at-the-university-of-washington/)
#   - [Advanced Graduate Data Science Option](https://escience.washington.edu/education/phd/advanced-phd-data-science-option/)

# %% [markdown]
# ## Physics
#
# - [Introduction to Electricity and Magnetism Specialization](https://www.coursera.org/specializations/introduction-to-electricity-magnetism#courses)
# - [Introduction to Mechanics Specialization](https://www.coursera.org/specializations/introduction-to-mechanics#courses)

# %% [markdown]
# ## Mathematics

# %% [markdown]
# - **CMPSC 360: Discrete Mathematics for Computer Science**
#   - Description: Discrete mathematics and foundations for modern computer science.
#   - Concurrent: CMPSC 122
#   - Alternatives:
#     - [Discrete Mathematics](https://www.coursera.org/learn/discrete-mathematics)
#     - [Mathematics for computer Science](https://www.coursera.org/learn/mathematics-for-computer-science)
#     - [Data Science Math Skills](https://www.coursera.org/learn/datasciencemathskills)
#     - [Discrete Mathematics Study Center](https://cglab.ca/~discmath/index.html)
#     - [CS381 Discrete Structures/Discrete Mathematics Web Course Material](https://www.cs.odu.edu/~toida/nerzic/content/web_course.html)
#     - [CS390 Introduction to Theoretical Computer Science/Theory of Computation](https://www.cs.odu.edu/~toida/nerzic/390teched/web_course.html)
#     - [Mathematics for Computer Science](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-fall-2010/)
#     - [Study Notes for Discrete Mathematics](https://www.math.uvic.ca/faculty/gmacgill/guide/index.html)
#     - [CSE 547 Discrete Mathematics Lectures](https://www3.cs.stonybrook.edu/~algorith/math-video/)
#     - [Discrete Mathematics: An Open Introduction ebook](http://discrete.openmathbooks.org/dmoi3/sec_intro-intro.html)
#     - [Discrete Mathematics](https://www.tutorialspoint.com/discrete_mathematics/index.htm)
#     - [UW CSE311 CSE 311: Foundations of Computing I](https://courses.cs.washington.edu/courses/cse311/)
#     - [UW CSE311 CSE 312: Foundations of Computing II](http://courses.cs.washington.edu/courses/cse312/)
#     - [MIT Mathematics for Computer Science](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-fall-2010/)
#     - [MIT Principles of Discrete Applied Mathematics](https://ocw.mit.edu/courses/mathematics/18-310-principles-of-discrete-applied-mathematics-fall-2013/index.htm)
# - **MATH 140: Calculus with Analytic Geometry I**
#   - Description: Functions, limits; analytic geometry; derivatives, differentials; integrals.
#   - Alternatives:
#     - [YouTube/freeCodeCamp - Complete Calculus Course](https://www.youtube.com/watch?v=HfACrKJ_Y2w)
#     - [Khan Academy - Analytic Geometry](https://www.khanacademy.org/math/geometry-home/analytic-geometry-topic)
#     - [Khan Academy - Calculus 1](https://www.khanacademy.org/math/calculus-1)
#     - [Coursera - Differential Calculus through Data and Modeling Specialization](https://www.coursera.org/specializations/differential-calculus-data-modeling#courses)
#     - [Coursera - Integral Calculus through Data and Modeling Specialization](https://www.coursera.org/specializations/integral-calculus-data-modeling#courses)
#     - [Coursera - Mathematics for Machine Learning: Multivariate Calculus](https://www.coursera.org/learn/multivariate-calculus-machine-learning)
#     - [EdX - MIT Single Variable Calculus](https://www.edx.org/xseries/mitx-18.01x-single-variable-calculus)
#     - [Calculus: Early Transcendentals 8th Edition by James Stewart (covers all levels of calculus)](https://www.amazon.com/Calculus-Early-Transcendentals-James-Stewart/dp/1285741552)
# - **MATH 141: Calculus with Analytic Geometry II**
#   - Description: Derivatives, integrals, applications; sequences and series; analytic geometry; polar coordinates. This course covers the following topics: logarithms, exponentials, and inverse trigonometric functions; applications of the definite integral and techniques of integration; sequences and series; power series and Taylor polynomials; parametric equations and polar functions.
#   - Prerequisite: MATH 140
#   - Alternatives:
#     - [Khan Academy - Calculus 2](https://www.khanacademy.org/math/calculus-2)
#     - [Edx - MIT Multivariable Calculus 1: Vectors and Derivatives](https://www.edx.org/course/multivariable-calculus-1-vectors-and-derivatives)
#     - [Coursera - Mathematics for Machine Learning: PCA](https://www.coursera.org/learn/pca-machine-learning)
# - **MATH 220: Matrices**
#   - Description: Systems of linear equations; matrix algebra; eigenvalues and eigenvectors; linear systems of differential equations. The initial portion of the course teaches the fundamentals of solving linear systems. This requires the language and notation of matrices and fundamental techniques for working with matrices such as row and column operations, echelon form, and invertibility. The determinant of a matrix is also introduced; it gives a test for invertibility. In the second part of the course the key ideas of eigenvector and eigenvalue are developed. These allow one to analyze a complicated matrix problem into simpler components and appear in many disguises in physical problems. The course also introduces the concept of a vector space, a crucial element in future linear algebra courses.
#   - Prerequisites: MATH 140
#   - Alternatives:
#     - [Khan Academy - Linear Algebra](https://www.khanacademy.org/math/linear-algebra)
#     - [Coursera - Mathematics for Machine Learning: Linear Algebra](https://www.coursera.org/learn/linear-algebra-machine-learning)
# - **MATH 250: Ordinary Differential Equations**
#   - Description: First- and second-order equations; special functions; Laplace transform solutions; higher order equations.
#   - Prerequisite: MATH 141
#   - Alternatives:
#     - [Khan Academy - Differential Equations](https://www.khanacademy.org/math/differential-equations)
#     - [Edx - MIT Introduction to Differential Equations](https://www.edx.org/course/introduction-to-differential-equations-2)
#     - [Edx - MIT Differential Equations: 2x2 Systems](https://www.edx.org/course/differential-equations-2x2-systems)
#     - [Edx - MIT Differential Equations: Fourier Series and Partial Differential Equations](https://www.edx.org/course/differential-equations-fourier-series-and-partial)
#     - [Edx - MIT Transfer Functions and the Laplace Transform](https://www.edx.org/course/transfer-functions-and-the-laplace-transform)
# - **STAT 500: Applied Statistics**
#   - Description: Descriptive statistics, hypothesis testing, power, estimation, confidence intervals, regression, one- and 2-way ANOVA, Chi-square tests, diagnostics.
#   - Alternatives:
# - **STAT 502: Analysis of Variance and Design of Experiments**
#   - Description: Analysis of variance and design concepts; factorial, nested, and unbalanced data; ANCOVA; blocked, Latin square, split-plot, repeated measures designs
# - **STAT 510: Applied Time Series Analysis**
#   - Description: Identification of models for empirical data collected over time. Use of models in forecasting.
#   - Prerequisite: STAT 462 or STAT 501 or STAT 511
#   - Alternatives:

# %% [markdown]
# ### MITOpenCourseware Math with video lectures
#
# - [MIT A 202 Vision of Linear Algebra - Supplement](https://ocw.mit.edu/resources/res-18-010-a-2020-vision-of-linear-algebra-spring-2020/)
# - [MIT 18.065 Matrix Methods in Data Analysis, Singal Processing, and Machine Learning](https://ocw.mit.edu/courses/mathematics/18-065-matrix-methods-in-data-analysis-signal-processing-and-machine-learning-spring-2018/)
# - [MIT RES.LL-005 Mathematics of Big Data and Machine Learning](https://ocw.mit.edu/resources/res-ll-005-mathematics-of-big-data-and-machine-learning-january-iap-2020/)
# - [MIT 18.217 Graph Theory and Additive Combinatorics](https://ocw.mit.edu/courses/mathematics/18-217-graph-theory-and-additive-combinatorics-fall-2019/)
# - [MIT 18.650 Statistics for Applications](https://ocw.mit.edu/courses/mathematics/18-650-statistics-for-applications-fall-2016/)
# - [MIT 18.01 Single Variable Calculus](https://ocw.mit.edu/courses/mathematics/18-01-single-variable-calculus-fall-2006/)
# - [Calculus Revisited: Single Variable Calculus](https://ocw.mit.edu/resources/res-18-006-calculus-revisited-single-variable-calculus-fall-2010/)
# - [MIT 18.02 Multivariable Calculus](https://ocw.mit.edu/courses/mathematics/18-02-multivariable-calculus-fall-2007/)
# - [Calculus Revisited: Multivariable Calculus](https://ocw.mit.edu/resources/res-18-007-calculus-revisited-multivariable-calculus-fall-2011/)
# - MIT 18.03 Differential Equations
#   - [Spring 2010](https://ocw.mit.edu/courses/mathematics/18-03-differential-equations-spring-2010/index.htm)
#    - [Fall 2011](https://ocw.mit.edu/courses/mathematics/18-03sc-differential-equations-fall-2011/)
# - [Learn Differential Equations: Up Close with Gilbert Strang and Cleve Moler - Supplement](https://ocw.mit.edu/resources/res-18-009-learn-differential-equations-up-close-with-gilbert-strang-and-cleve-moler-fall-2015/)
# - [Highlights of Calculus - Supplement](https://ocw.mit.edu/resources/res-18-005-highlights-of-calculus-spring-2010/)
# - [Calculus Revisited: Complex Variables, Differential Equations, and Linear Algebra](https://ocw.mit.edu/resources/res-18-008-calculus-revisited-complex-variables-differential-equations-and-linear-algebra-fall-2011/)
# - [MIT 18.404J Theory of Computation](https://ocw.mit.edu/courses/mathematics/18-404j-theory-of-computation-fall-2020/)
# - MIT 18.06 Linear Algeabra
#   - [Fall 2011](https://ocw.mit.edu/courses/mathematics/18-06sc-linear-algebra-fall-2011/)
#   - [Spring 2010](https://ocw.mit.edu/courses/mathematics/18-06-linear-algebra-spring-2010/)
# - [MIT 18.062J / 6.042J Mathematics for Computer Science](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-spring-2015/)
# - [MIT 18.410J / 6.046J Design and Analysis of Algorithms](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-046j-design-and-analysis-of-algorithms-spring-2015/)
# - [MIT 18.S191 / 6.S083 Introduction to Computational Thinking](https://ocw.mit.edu/courses/mathematics/18-s191-introduction-to-computational-thinking-fall-2020/)

# %% [markdown]
# ## Computer Science

# %% [markdown]
# - **CMPEN 270: Design Theory and Practice**
#   - Description: Introduction to digital systems and their design. Topics include combinational and sequential devices and circuits, modern design tools and design practices. The course introduces the theoretical foundation for digital systems including number systems, a variety of commonly used codes and Boolean algebra. Combinational devices, logic gates, and sequential devices, latches and flip-flops are introduced along with design techniques, methods and tools. Design criteria and objectives are considered and design trade-offs are examined. Higher level design elements are also examined such as decoders, multiplexers, counters, and registers, and their use in system design. Students are exposed to a variety of design tools and implementation techniques, including schematic capture tools, simulation tools, Hardware Description Languages (HDL) and HDL design tools. Laboratory work includes the design, construction and debugging of a variety of digital circuits, and the use of standard laboratory tools such as the oscilloscope and logic analyzer, and various software design tools.
#   - Alternatives:
#     - [Udacity - Intro to Theoretical Computer Science](https://www.udacity.com/course/intro-to-theoretical-computer-science--cs313)
#     - [Coursera - How Computers Work](https://www.coursera.org/learn/how-computers-work)
#     - [Coursera - Introduction to Computer Information Systems Specialization](https://www.coursera.org/specializations/introduction-computer-infosystems)
#     - [Coursera - Digital Systems: From Logic Gates to Processors](https://www.coursera.org/learn/digital-systems)
#     - [Coursera - Build a Modern Computer from First Principles: From Nand to Tetris (Project-Centered Course)](https://www.coursera.org/learn/build-a-computer)
# - **CMPEN 351: Microprocessors**
#   - Description: Microprocessor architecture; memory system design; assembly language programming; interrupts; the stacks and subroutines; memory and I/O inter-facing; serial I/O and data communications; microprocessors applications.
#   - Prerequisites: CMPEN 270 or CMPEN 271 and CMPEN 275
#   - Alternatives:
#     - [Coursera - Computer Architecture](https://www.coursera.org/learn/comparch)
#     - [Coursera - Linux:I/O Redirection for DevOps](https://www.coursera.org/projects/rudi-hinds-linux-io-redirection-for-devops)
#     - [Coursera - Introduction to Operating Systems Specialization](https://www.coursera.org/specializations/codio-introduction-operating-systems)
# - **CMPEN 441: Operating Systems**
#   - Description: Resource management in computer systems. Process scheduling, memory management, file system design, I/O management, Unix operating system.
#   - Prerequisite: CMPSC 360
#   - Alternatives:
#     - [Udacity - Introduction to Operating Systems](https://www.udacity.com/course/introduction-to-operating-systems--ud923)
#     - [Udacity - Advanced Operating Systems](https://www.udacity.com/course/advanced-operating-systems--ud189)
# - **CMPEN 461: Communication Networks**
#   - Description: Data transmission, encoding, link control techniques, network architecture, design, protocols, and multiple access. This course introduces students to fundamental concepts and principles underlying data communication networks, with an emphasis on the Internet and its five-layer architecture: the application, transport, network, link, and physical layers. The fundamental issues to be covered include, but not limited to, reliable communication over an unreliable network layer, connection establishment/teardown and handshaking, congestion and flow control, path determination, multiple access control. The student learning these principles will gain knowledge that lasts long after today's network standards and protocols have become obsolete.
#   - Prerequisites: CMPEN 270 or CMPEN 271; CMPSC 121 or CMPSC 201
#   - Alternatives:
#     - [Udacity - Computer Networking](https://www.udacity.com/course/computer-networking--ud436)
#     - [Udacity - Networking for Web Developers](https://www.udacity.com/course/networking-for-web-developers--ud256)
#     - [Coursera - Software Defined Networking](https://www.coursera.org/learn/sdn)
#     - [Coursera - Computer Communications Specialization](https://www.coursera.org/specializations/computer-communications)
#     - [Coursera - Networks and Communications Security](https://www.coursera.org/learn/network-security-communications-sscp)
# - **CMPSC 121: Introduction to Programming Techniques**
#   - Description: Design and implementation of algorithms. Structured programming. Problem solving techniques. Introduction to a high-level language, including arrays, procedures, and recursion.
#   - Prerequisite: MATH 110 or prerequisite or concurrent MATH 140
#   - Alternatives:
#     - [UW CSE 140/160 - Introduction to data programming with applications](https://homes.cs.washington.edu/~mernst/teaching/data-programming/)
#     - [UW CSE 190 - Java Programming Seminar for CSE 140](https://courses.cs.washington.edu/courses/cse190d/13wi/textbook.shtml)
#     - [Udacity - Intro to JavaScript](https://www.udacity.com/course/intro-to-javascript--ud803)
#     - [Udacity - Design of Computer Programs](https://www.udacity.com/course/design-of-computer-programs--cs212)
#     - [Coursera - Computational Thinking for Problem Solving](https://www.coursera.org/learn/computational-thinking-problem-solving)
# - **CMPSC 122: Intermediate Programming**
#   - Description: Object-oriented programming, recursion, fundamental data structures (including stacks, queues, linked lists, hash tables, trees, and graphs), the basics of algorithmic analysis, and an introduction to the principles of language translation.
#   - Prerequisite: CMPSC 121
#   - Alternatives:
#     - [UW CSE 163 - Intermediate Data Programming](https://courses.cs.washington.edu/courses/cse163/22wi/)
# - **SWENG 311: Object-oriented Software Design and Construction**
#   - Description: Design, documentation, testing, and construction of software using software engineering strategies embodied in object-oriented programming languages.
#   - Prerequisite: CMPSC 122
#   - Alternatives:
#     - [Udacity - Object-Oriented JavaScript](https://www.udacity.com/course/object-oriented-javascript--ud711)
# - **CMPSC 461: Programming Language Concepts**
#   - Description: Fundamental concepts of programming language design, specifications, and implementation; programming language paradigms and features; program verification.
#   - Prerequisites: CMPSC 221 or SWENG 311; CMPSC 360
#   - Alternatives:
# - **CMPSC 465: Data Structures and Algorithms**
#   - Description: Fundamental concepts of computer science: data structures, analysis of algorithms, recursion, trees, sets, graphs, sorting.
#   - Prerequisites: CMPSC 122; CMPSC 360 or MATH 311W
#   - Alternatives:
#     - [Udacity - Introduction to Graduate Algorithms](https://www.udacity.com/course/introduction-to-graduate-algorithms--ud401)
#     - [Udacity - Intro to Algorithms](https://www.udacity.com/course/intro-to-algorithms--cs215)
#     - [Udacity - Computability, Complexity, & Algorithms](https://www.udacity.com/course/computability-complexity-algorithms--ud061)
#     - [Cousera - Data Science Foundations: Data Structures and Algorithms Speciialization](https://www.coursera.org/specializations/boulder-data-structures-algorithms)
# - **SWENG 411: Software Engineering**
#   - Description: Software engineering principles including lifecycle, dependability, process modeling, project management, requires specification, design analysis, implementation, testing, and maintenance.
#   - Prerequisite: CMPSC 122; Concurrent: SWENG 311
#   - Alternatives:
#     - [Udacity - Software Development Process](https://www.udacity.com/course/software-development-process--ud805)
#     - [Udacity - Continuous Integration & Deployment](https://www.udacity.com/course/continuous-integration-and-deployment--ud1030)
#     - [Udacity - Intro to Devops](https://www.udacity.com/course/intro-to-devops--ud611)
#     - [Coursera - Software Development Lifecycle Specialization](https://www.coursera.org/specializations/software-development-lifecycle)
# - **SWENG 431: Software Verification, Validation, and Testing**
#   - Description: Introduction to methods of software verification, validation, and testing; mathematical foundations of testing, reliability models; statistical testing.
#   - Prerequisites: SWENG 411; STAT 301
#   - Alternatives:
#     - [Udacity - Software Analysis & Testing](https://www.udacity.com/course/software-analysis-testing--ud333)
#     - [Udacity - JavaScript Testing](https://www.udacity.com/course/javascript-testing--ud549)
#     - [Udacity - Software Testing](https://www.udacity.com/course/software-testing--cs258)
#     - [Udacity - Software Debugging](https://www.udacity.com/course/software-debugging--cs259)
#     - [Coursera - Software Testing and Automation Specialization](https://www.coursera.org/specializations/software-testing-automation)
# - **SWENG 421: Software Architecture**
#   - Description: The analysis and design of software systems using canonical design patterns.
#   - Prerequisite: SWENG 411
#   - Alternatives:
#     - [Udacity - Software Architecture & Design](https://www.udacity.com/course/software-architecture-design--ud821)
#     - [Coursera - Software Design and Architecture Specialization](https://www.coursera.org/specializations/software-design-architecture)
# - **SWENG 452: Embedded Real Time Systems**
#   - Description: The design and implementation of real time systems.
#   - Prerequisites: CMPSC 472 or CMPSC 473 or CMPEN 441
#   - Alternatives:
#     - [Coursera - Real-Time Embedded Systems Specialization](https://www.coursera.org/specializations/real-time-embedded-systems)
# - **SWENG 480: Software Engineering Design**
#   - Description: Concepts of engineering ethics, economy, and project management, senior capstone project selection, and technical communication skills.
#   - Prerequisite: SWENG 431
#   - Alternatives:
# - **SWENG 481: Software Engineering Project (capstone)**
#   - Description: Capstone group design projects in software engineering.
#   - Prerequisite: SWENG 480
#   - Alternatives:
# - **SWENG 585: Pattern-Oriented Design**
#   - Description:
#   - Alternatives:

# %% [markdown]
# ### MIT OpenCourseware Computer Science with video lectures
#
# - [MIT 6.001 Structure and Interpretation of Computer Programs](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-001-structure-and-interpretation-of-computer-programs-spring-2005/index.htm)
# - [MIT 6.002 Circuits and Electronics](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-002-circuits-and-electronics-spring-2007/)
# - [MIT 6.003 Signals and Systems](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-003-signals-and-systems-fall-2011/)
# - [MIT 6.004 Computation Structures](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-004-computation-structures-spring-2017/)
# - MIT 6.006 Introduction to Algorithms
#   - [Spring 2020](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-006-introduction-to-algorithms-spring-2020/)
#   - [Fall 2011](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-006-introduction-to-algorithms-fall-2011/)
# - [MIT 6.046J / 18.410J Introduction to Algorithms](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-046j-introduction-to-algorithms-sma-5503-fall-2005/)
# - [MIT 6.02 Introduction to EECS II: Digital Communication Sysstems](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-02-introduction-to-eecs-ii-digital-communication-systems-fall-2012/)
# - [MIT 6.034 Artificial Intelligence](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-034-artificial-intelligence-fall-2010/)
# - [MIT 6.035 Computer Language Engineering](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-035-computer-language-engineering-sma-5502-fall-2005/)
# - [MIT 6.036 Introduction to Machine Learning](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-036-introduction-to-machine-learning-fall-2020/)
# - MIT 6.041 / 6.431 Probabilistic Systems Analysis and Applied Probability
#   - [Fall 2010](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-041-probabilistic-systems-analysis-and-applied-probability-fall-2010/)
#   - [Fall 2013](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-041sc-probabilistic-systems-analysis-and-applied-probability-fall-2013/)
# - [MIT 6.189 Multicore Programming Primer](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-189-multicore-programming-primer-january-iap-2007/)
# - [MIT 6.252J Nonlinear Programming](https://ocw.mit.edu/courses/sloan-school-of-management/15-084j-nonlinear-programming-spring-2004/)
# - [MIT 6.262 Discrete Stochastic Processes](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-262-discrete-stochastic-processes-spring-2011/)
# - [MIT 6.450 Principles of Digital Communications I](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-450-principles-of-digital-communications-i-fall-2006/)
# - [MIT 6.450 Principles of Digital Communications II](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-451-principles-of-digital-communication-ii-spring-2005/)
# - [MIT 6.851 Advanced Data Structures](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-851-advanced-data-structures-spring-2012/)
# - [MIT 6.868J The Society of Mind](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-868j-the-society-of-mind-fall-2011/)
# - [MIT 6.890 Algorithmic Lower Bounds: Fun with Hardness Proofs](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-890-algorithmic-lower-bounds-fun-with-hardness-proofs-fall-2014/)
# - [MIT 6.S191 Introduction to Deep Learning](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-s191-introduction-to-deep-learning-january-iap-2020/)
# - [Electromagnetic Fields and Energy - Supplement](https://ocw.mit.edu/resources/res-6-001-electromagnetic-fields-and-energy-spring-2008/)
# - [Signals and Systems - Supplement](https://ocw.mit.edu/resources/res-6-007-signals-and-systems-spring-2011/)
# - [Digital Signal Processing - Supplement](https://ocw.mit.edu/resources/res-6-008-digital-signal-processing-spring-2011/)

# %% [markdown]
# ### University of Washington Computer Science courses
#
# - [CSE 120: Computer Science Principles](http://courses.cs.washington.edu/courses/cse120/)
#   - Description: Introduces fundamental concepts of computer science and computational thinking. Includes logical reasoning, problem solving, data representation, abstraction, the creation of “digital artifacts” such as Web pages and programs, managing complexity, operation of computers and networks, effective Web searching, ethical, legal and social aspects of information technology.
# - [CSE 142: Computer Programming I](http://courses.cs.washington.edu/courses/cse142/)
#   - Description: Basic programming-in-the-small abilities and concepts including procedural programming (methods, parameters, return, values), basic control structures (sequence, if/else, for loop, while loop), file processing, arrays, and an introduction to defining objects. Intended for students without prior programming experience
# - [CSE 143: Computer Programming II](http://courses.cs.washington.edu/courses/cse143/)
#   - Description: Continuation of 142. Concepts of data abstraction and encapsulation including stacks, queues, linked lists, binary trees, recursion, instruction to complexity and use of predefined collection classes.
#   - Prerequisites: CSE 142
# - [CSE 154: Web Programming](http://courses.cs.washington.edu/courses/cse154/)
#   -  Description: Covers languages, tools, and techniques for developing interactive and dynamic web pages. Topics include page styling, design, and layout; client and server side scripting; web security; and interacting with data sources such as databases.
#   - Prerequisite: either CSE 142, CSE 143, or CSE 160
# - [CSE 160]()
# - [CSE 163](https://courses.cs.washington.edu/courses/cse163/22wi/)
#   - Description: Intermediate data programming. Topics include writing programs that manipulate different types of data; leveraging the growing ecosystem of tools and libraries for data programming; writing programs that are both efficient and elegant; and writing medium-scale programs (100 to 200 lines).
#   - Prerequisite: CSE 142 or CSE 160
#   - [Intermediate Data Programming ebook](https://cse163.github.io/book/index.html)
#   - [Github page](https://github.com/cse163/book)
# - [CSE 180: Introduction to Data Science](http://courses.cs.washington.edu/courses/cse180/)
#   - Description: Survey course introducing the essential elements of data science: data collection, management, curation, and cleaning; summarizing and visualizing data; basic ideas of statistical inference, machine learning. Students will gain hands-on experience through computing labs.
#   - Prerequisite: Either MATH 098, MATH 103, a score of 151-169 on the MPT-GS placement test, or score of 145-153 on the MPT-AS placement test
# - [CSE 190D: Java Programming Seminar](https://courses.cs.washington.edu/courses/cse190d/13wi/textbook.shtml)
#   - Description: In CSE 190 D, we will learn how to do the tasks that CSE 140 teaches in Python, in Java. This seminar is meant to prepare you to skip CSE 142 and enter directly into CSE 143.
#   - Prerequisite: CSE 140
# - [CSE 311: Foundations of Computing I](http://courses.cs.washington.edu/courses/cse311/)
#   - Description: Examines fundamentals of logic, set theory, induction, and algebraic structures with applications to computing; finite state machines; and limits of computability.
#   - Prerequisite: CSE 143; either MATH 126 or MATH 136.
# - [CSE 312: Foundations of Computing II](http://courses.cs.washington.edu/courses/cse312/)
#   - Description: Examines fundamentals of enumeration and discrete probability; applications of randomness to computing; polynomial-time versus NP; and NP-completeness. Prerequisite: CSE 311.
#   - Prerequisites: CSE 311
# - [CSE 331: Software Design and Implementation](http://courses.cs.washington.edu/courses/cse331/)
#   - Description: Explores concepts and techniques for design and construction of reliable and maintainable software systems in modern high-level languages; program structure and design; program-correctness approaches, including testing; and event-driven programming (e.g., graphical user interface). Includes substantial project and software-team experience.
#   - Prerequisite: CSE 143
# - [CSE 344: Introduction to Data Management](http://courses.cs.washington.edu/courses/cse344/)
#   - Description: Introduces database management systems and writing applications that use such systems; data models (e.g., relational, semi-structured), query languages (e.g., SQL, XQuery), language bindings, conceptual modeling, transactions, security, database tuning, data warehousing, parallelism, and web-data management.
#   - Prerequisites: CSE 311
# - [CSE 332: Data Structures and Parallelism](http://courses.cs.washington.edu/courses/cse332/)
#   - Description: Covers abstract data types and structures including dictionaries, balanced trees, hash tables, priority queues, and graphs; sorting; asymptotic analysis; fundamental graph algorithms including graph search, shortest path, and minimum spanning trees; concurrency and synchronization; and parallelism.
#   - Not available for credit for students who have completed CSE 373.
#   - Prerequisite: CSE 311
# - [CSE 373: Data Structures and Algorithms](http://courses.cs.washington.edu/courses/cse373/)
#   - Description: Fundamental algorithms and data structures for implementation. Techniques for solving problems by programming. Linked lists, stacks, queues, directed graphs. Trees: representations, traversals. Searching (hashing, binary search trees, multiway trees). Garbage collection, memory management. Internal and external sorting. Intended for non-majors.
#   - Not open for credit to students who have completed CSE 332.
#   - Prerequisite: CSE 143
# - [CSE 333: Systems Programming](http://courses.cs.washington.edu/courses/cse333/)
#   - Description: Includes substantial programming experience in languages that expose machine characteristics and low-level data representation (e.g., C and C++); explicit memory management; interacting with operating-system services; and cache-aware programming.
#   - Prerequisite: CSE 351
# - [CSE 341: Programming Languages](http://courses.cs.washington.edu/courses/cse341/)
#   - Description: Basic concepts of programming languages, including abstraction mechanisms, types, and scoping. Detailed study of several different programming paradigms, such as functional, object-oriented, and logic programming.
#   - No credit if CSE 413 has been taken.
#   - Prerequisites: CSE 143
# - [CSE 351: The Hardware/Software Interface](http://courses.cs.washington.edu/courses/cse351/)
#   - Description: Examines key computational abstraction levels below modern high-level languages; number representation, assembly language, introduction to C, memory management, the operating-system process model, high-level machine architecture including the memory hierarchy, and how high-level languages are implemented.
#   - Prerequisite: CSE 143
# - [CSE 352: Hardware Design and Implementation](http://courses.cs.washington.edu/courses/cse352/)
#   - Description: Covers digital circuit design, processor design, and systems integration and embedded-systems issues. Include substantial hardware laboratory.
#   - Prerequisites: CSE 311; CSE 351
# - [CSE 369: Introduction to Digital Design](https://courses.cs.washington.edu/courses/cse369/)
#   - Description: Introduces the implementation of digital logic and its specification and simulation. Covers Boolean algebra; combinational circuits including arithmetic circuits and regular structures; sequential circuits including finitestate-machines; and use of field-programmable gate arrays (FPGAs). Emphasizes simulation, high-level specification, and automatic synthesis techniques.
#   - Prerequisite: CSE 311.
# - [CSE 374: Intermediate Programming Concepts and Tools](http://courses.cs.washington.edu/courses/cse374/)
#   - Description: Covers key software development concepts and tools not in introductory courses. Concepts of lower-level programming (C/C++) and explicit memory management; techniques and tools for individual and group software development; design, implementation, and testing strategies. Intended for non-majors. Cannot be taken for credit if credit received for CSE 333.
#   - Prerequisite: CSE 143
# - [CSE 391: System and Software Tools](http://courses.cs.washington.edu/courses/cse391/)
#   - Description: Introduction to tools commonly used in software development. Topics include using a command-line interface, writing scripts for file and string manipulation, managing user permissions, manipulating text with regular expressions, using build-management tools, and using version-control systems.
#   - Prerequisite: CSE 143
# - [CSE 403: Software Engineering](http://courses.cs.washington.edu/courses/cse403/)
#   - Description: Fundamentals of software engineering using a group project as the basic vehicle. Topics covered include the software crisis, managing complexity, requirements specification, architectural and detailed design, testing and analysis, software process, and tools and environments.
#   - Prerequisite: CSE 331; CSE 332.
# - [CSE 410: Computer Systems](http://courses.cs.washington.edu/courses/cse410/)
#   - Description: Structure and components of hardware and software systems. Machine organization, including central processor and input-output architectures; assembly language programming; operating systems, including process, storage, and file management. No credit to students who have completed 378 or 451
# - [CSE 451: Introduction to Operating Systems](http://courses.cs.washington.edu/courses/cse451/)
#   - Description: Principles of operating systems. Process management, memory management, auxiliary storage management, resource allocation. No credit to students who have completed CSE 410.
#   - Prerequisite: CSE 351; CSE 332; CSE 333
# - [CSE 452: Distributed Systems](http://courses.cs.washington.edu/courses/cse452/)
#   -  Description: Covers abstractions and implementation techniques in the construction of distributed systems, including cloud computing, distributed storage systems, and distributed caches.
#   - Prerequisites: CSE 332 and CSE 333; recommended: CSE 451
# - [CSE 412: Introduction to Data Visualization](http://courses.cs.washington.edu/courses/cse412/)
#   - Description: Introduction to data visualization design and use for both data exploration and explanation. Methods for creating effective visualizations using principles from graphic design, psychology, and statistics. Topics include data models, visual encoding methods, data preparation, exploratory analysis, uncertainty, cartography, interaction techniques, visual perception, and evaluation methods. No credit if CSE 442 taken.
#   - Prerequisite: CSE 143 or CSE 163
# - [CSE 442: Data Visualization](http://courses.cs.washington.edu/courses/cse442/)
#   - Description: Techniques for creating effective visualizations of data based on principles from graphic design, perceptual psychology, and statistics. Topics include visual encoding models, exploratory data analysis, visualization software, interaction techniques, graphical perception, color, animation, high-dimensional data, cartography, network visualization, and text visualization.
#   - Prerequisites: CSE 332
# - [CSE 415: Introduction to AI](http://courses.cs.washington.edu/courses/cse415/)
#   - Description: Principles and programming techniques of artificial intelligence: LISP, symbol manipulation, knowledge representation, logical and probabilistic reasoning, learning, language understanding, vision, expert systems, and social issues.
#   - Not open for credit to students who have completed 473.
#   - Prerequisites: CSE 373
# - [CSE 417: Algorithms and Computational Complexity](http://courses.cs.washington.edu/courses/cse417/)
#   - Description: Design and analysis of algorithms and data structures. Efficient algorithms for manipulating graphs and strings. Fast Fourier Transform. Models of computation, including Turing machines. Time and space complexity. NP-complete problems and undecidable problems
#   - Prerequisites: CSE 373
# - [CSE 421: Introduction to Algorithms](http://courses.cs.washington.edu/courses/cse421/)
#   - Description: Techniques for design of efficient algorithms. Methods for showing lower bounds on computational complexity. Particular algorithms for sorting, searching, set manipulation, arithmetic, graph problems, pattern matching.
#   - Prerequisites: CSE 312; CSE 332
# - [CSE 422: Advanced Toolkit for Modern Algorithms](https://courses.cs.washington.edu/courses/cse422/) - No material as of 3/19/2022
#   - Description: A rigorous introduction to the principles of modern algorithm design, with a particular focus on the analysis of large, noisy data sets, and the algorithmic principles underlying modern statistics and machine learning. Students reason about and implement contemporary algorithms, and analyze their behavior on real-world data sets.
# - [CSE 431: Introduction to Theory of Computation](http://courses.cs.washington.edu/courses/cse431/)
#   - Description: Models of computation, computable and noncomputable functions, space and time complexity, tractable and intractable functions.
#   - Prerequisite: CSE 312
# - [CSE 444: Database Systems Internals](http://courses.cs.washington.edu/courses/cse444/)
#   - Description: The relational data model and the SQL query language. Conceptual modeling: entity/relationships, normal forms. XML, XPath, and XQuery. Transactions: recovery and concurrency control. Implementation of a database system. A medium sized project using a rational database backend.
#   - Prerequisite: CSE 332; CSE 344
# - [CSE 447: Natural Language Processing](http://courses.cs.washington.edu/courses/cse447/)
#   - Description: Methods for designing systems that usefully and/or intelligently process natural language text data. Language models, text categorization, syntactic and semantic analysis, machine translation. This course emphasizes algorithms and data-driven methods.
#   - Prerequisite: CSE 312 and CSE 332; recommended: MATH 308 ; CSE 446 is recommended before or concurrently
# - [CSE 455: Computer Vision](http://courses.cs.washington.edu/courses/cse455/)
#   - Description: Introduction to image analysis and interpreting the 3D world from image data. Topics may include segmentation, motion estimation, image mosaics, 3D-shape reconstruction, object recognition, and image retrieval.
#   - Prerequisite: CSE 333; CSE 332.
# - [CSE 461: Introduction to Computer Communication Networks](http://courses.cs.washington.edu/courses/cse461/)
#   - Description: Computer network architectures, protocol layers, network programming. Transmission media, encoding systems, switching, multiple access arbitration. Network routing, congestion control, flow control. Transport protocols, real-time, multicast, network security.
#   - Prerequisites: CSE 326 or CSE 332; either CSE 303 or CSE 333
# - [CSE 466: Software for Embedded Systems](http://courses.cs.washington.edu/courses/cse466/)
#   - Description: Software issues in the design of embedded systems. Microcontroller architectures and peripherals, embedded operating systems and device drivers, compilers and debuggers, timer and interrupt systems, interfacing of devices, communications and networking. Emphasis on practical application of development platforms.
#   - Prerequisites: CSE 333; CSE 352
# - [CSE 469: Computer Architecture I](https://courses.cs.washington.edu/courses/cse469/)
#   - Description: Introduction to computer architecture. Assembly and machine language, microprocessor organization including control and datapath. Computer arithmetic. Memory systems and caching. Performance modeling of microprocessors.
#   - Prerequisite: either E E 271 or CSE 369; CSE 143 Offered: jointly with E E 469
# - [CSE 470: Computer Architecture II](http://courses.cs.washington.edu/courses/cse470/)
#   - Description: Advanced computer architecture. Performance evaluation and energy efficiency. Instruction set architectures. Instruction-level parallelism. Modern microprocessor micro-architecture. Thread-level parallelism. Cache coherency and memory consistency in shared-memory multiprocessors. Memory hierarchy. GPU architecture. Warehouse-scale computing. Trends in computer design.
#   - Prerequisite: CSE 351; either CSE 469, E E 469, or E E 471. Offered: jointly with E E 470
# - [CSE 490H: Distributed Systems](http://courses.cs.washington.edu/courses/cse490h/)
#   - Description: Distributed systems have become central to many aspects of how computers are used, from web applications to e-commerce to content distribution. This senior-level course will cover abstractions and implementation techniques for the construction of distributed systems, including client server computing, the web, cloud computing, peer-to-peer systems, and distributed storage systems. Topics will include remote procedure call, consistency of distributed state, fault tolerance, and security. We will also cover several case studies of distributed systems. A substantial programming project is involved.
#   - Prerequisites: (CSE 351 OR CSE 378) AND (CSE 326 OR CSE 332;) Strongly Recommended: CSE 451
# - [CSE 501: Programming Language Analysis And Implementation](http://courses.cs.washington.edu/courses/cse501/)
#   - Description: Design and implementation of compilers and run-time systems for imperative, object-oriented, and functional languages. Intra- and interprocedural analyses and optimizations.
#   - Prerequisite: CSE major and CSE 341; recommended CSE 401.
# - [CSEP 503: Software Engineering](http://courses.cs.washington.edu/courses/csep503/)
#   - Description: Study of major developments in software engineering over the past three decades. Topics may include design (information hiding, layering, open implementations), requirements specification (informal and formal approaches), quality assurance (testing, verification and analysis, inspections), reverse and re-engineering (tools, models, approaches).
# - [CSE 504: Advanced Topics In Software Engineering](http://courses.cs.washington.edu/courses/cse504/)
#   - Description: Topics vary but may include software design and evolution, formal methods, requirements specifications, software and system safety, reverse engineering, real-time software, metrics and measurement, programming environments, and verification and validation.
#   - Prerequisite: CSE major or permission of instructor.
# - [CSE 505: Principles Of Programming Languages]()
#   - Description: Design and formal semantics of modern programming languages, includes functional and object-oriented languages.
#   - Prerequisite: CSE major and CSE 341.
# - [CSE 506: Advanced Topics In Programming Languages]
#   - Description: May include functional, object-oriented, parallel, and logic programming languages; semantics for languages of these kinds; type declaration, inference, and checking (including polymorphic types); implementation issues, such as compilation, lazy evaluation, combinators, parallelism, various optimization techniques. Implementation project required.
#   - Prerequisite: CSE major, CSE 501 which may be taken concurrently, and CSE 505.
# - [CSE 512: Data Visualization](http://courses.cs.washington.edu/courses/cse512/)
#   - Description: Techniques and algorithms for creating effective visualizations based on principles from graphic design, visual art, perceptual psychology and cognitive science. Topics: data and image models, visual encoding, graphical perception, color, animation, interaction techniques, graph layout, automated design. Lectures, reading and project.
#   - Prerequisites: CSE 332 or 373 or equivalent.
# - [CSE 515: Statistical Methods In Computer Science](http://courses.cs.washington.edu/courses/cse515/)
#   - Description: Introduction to the probabilistic and statistical techniques used in modern computer systems. Graphical models, probabilistic inference, statistical learning, sequential models, decision theory.
#   - Prerequisite: either STAT 341 or STAT 391, and graduate standing in computer science, or permission of instructor.
# - [CSE 517: Natural Language Processing](http://courses.cs.washington.edu/courses/cse517/)
#   - Description: Overview of modern approaches for natural language processing. Topics include language models, text classification, tagging, parsing, machine translation, semantics, and discourse analysis.
# - [CSE 521: Design And Analysis Of Algorithms I](http://courses.cs.washington.edu/courses/cse521/)
#   - Description: Principles of design of efficient algorithms: recursion, divide and conquer, balancing, dynamic programming, greedy method, network flow, linear programming. Correctness and analysis of algorithms. NP-completeness.
#   - Prerequisite: CSE major and CSE 326 or equivalent. CSE majors only.
# - [CSE 522: Design And Analysis Of Algorithms II](http://courses.cs.washington.edu/courses/cse522/)
#   - Description: Analysis of algorithms more sophisticated than those treated in 521. Content varies and may include such topics as algebraic algorithms, combinational algorithms, techniques for proving lower bounds on complexity, and algorithms for special computing devices such as networks or formulas.
#   - Prerequisite: CSE major and CSE 521.
# - [CSE 523: Computational Geometry](http://courses.cs.washington.edu/courses/cse523/)
#   - Description: Algorithms for discrete computational geometry. Geometric computation, range searching, convex hulls, proximity, Vornoi diagrams, intersection. Application areas include VLSI design and computer graphics.
#   - Prerequisite: CSE major and CSE 521; recommended: CSE 457 or equivalent.
# - [CSE 524: Parallel Algorithms](http://courses.cs.washington.edu/courses/cse524/)
#   - Description: Design and analysis of parallel algorithms: fundamental parallel algorithms for sorting, arithmetic, matrix and graph problems and additional selected topics. Emphasis on general techniques and approaches used for developing fast and efficient parallel algorithms and on limitations to their efficacy.
#   - Prerequisite: CSE major and CSE 521.
# - [CSE 525: Randomized Algorithms And Probablisitc Analysis](http://courses.cs.washington.edu/courses/cse525/)
#   - Examines algorithmic techniques: random selection, random sampling, backwards analysis, algebraic methods, Monte Carlo methods, and randomized rounding; random graphs; the probabilistic method; Markov chains and random walks; and analysis tools: random variables, moments and deviations, Chernoff bounds, martingales, and balls in bins. Prerequisite: CSE 521 or equivalent; CSE majors only. Offered: WSp.
# - [CSEP 531: Computability and Complexity Theory](http://courses.cs.washington.edu/courses/csep531/)
#   - Description: Survey of the theory of computation including Turing Machines, Churche' s Thesis, computability, incompleteness, undecidability, complexity classes, problem reductions, Cook' s theorem, NP-completeness, randomized computation, cryptography, parallel computation, and space complexity. Some emphasis will be placed on historical and philosophical aspects of the theory of computation. Prerequisite: CSE PMP majors only.
# - [CSEP 544: Database Management Systems](http://courses.cs.washington.edu/courses/csep544/)
#   - Description: Introduction to the principles of database management systems. Topics include database system architecture, data models, theory of database design, query optimization, concurrency control, crash recovery, and storage strategies. CSE majors only.
# - [CSEP 548: Computer Architecture](http://courses.cs.washington.edu/courses/csep548/)
#   - Description: Architecture of the single-chip microprocessor: instruction set design and processor implementation (pipelining, multiple issue, speculative execution). Memory hierarchy: on-chip and off-chip caches, TLBs and their management, virtual memory from the hardware viewpoint. I/O devices and control: buses, disks, and RAIDs.
#   - Prerequisite: CSE majors only.
# - [CSEP 551: Computer Operating Systems](http://courses.cs.washington.edu/courses/csep551/)
#   - Description: A study of developments in operating systems from the 196' s to the present. Topics include operating system structure, protection, virtual memory, communication mechanisms, concurrency, lightweight threads, object-oriented systems, distributed systems, and transaction support in operating systems.
#   - Prerequisite: CSE majors only.
# - [CSEP 552: Distributed Systems](http://courses.cs.washington.edu/courses/csep552/)
#   - Description: Principles, techniques, and examples related to the design, implementation, and analysis of distributed computer systems. Prerequisite: CSE PMP majors only.
# - [CSEP 567: Design And Implementation Of Digital Systems](http://courses.cs.washington.edu/courses/csep567/)
#   - Description: Overview of current implementation technologies for digital systems including custom integrated circuits, field-programmable logic, and embedded processors. Systems components such as buses and communications structures, interfaces, memory architectures, embedded systems, and application-specific devices. Focus on the design of large systems using modern CAD tools.
#   - Prerequisite: CSE majors only.
# - [CSEP 573: Applications Of Artificial Intelligence](http://courses.cs.washington.edu/courses/csep573/)
#   - Introduction to the use of Artificial Intelligence tools and techniques in industrial and company settings. Topics include foundations (search, knowledge representation) and tools such as expert systems, natural language interfaces and machine learning techniques.
#   - Prerequisite: CSE majors only.
# - [CSEP 576: Computer Vision](http://courses.cs.washington.edu/courses/csep576/)
#   - Description: Provides an overview of computer vision, emphasizing the middle ground between image processing and artificial intelligence. Image formation, pre-attentive image processing, boundary and region representations, and case studies of vision architectures.
# - [CSE 583: Software Development for Data Scientists](http://uwseds.github.io/)
# - [CSEP 585: Design and Implementation of Digital Systems](https://courses.cs.washington.edu/course_archives/www_archive/cse585/)
#   - Description: Overview of current implementation technologies for digital systems including custom integrated circuits, field-programmable logic, and embedded processors. Systems components such as buses and communications structures, interfaces, memory architectures, embedded systems, and application-specific devices. Focus on the design of large systems using modern CAD tools.
# - [OCN 506A: Effective Computing (oceanography dept)](http://faculty.washington.edu/pmacc/Classes/EffCom_2020/index.html)
#
# #### Computer animation
#
# - [CSE 456: Story Design for Computer Animation](http://courses.cs.washington.edu/courses/cse456/)
#   - Description: Animation principles and production for story development and design. Design, development, and production of several storyreels, which are a tool for the pre-production of animated features and shorts. Student use authoring tools to present finished work.
# - [CSE 457: Computer Graphics](http://courses.cs.washington.edu/courses/cse457/)
#   -  Description: Introduction to computer image synthesis, modeling, and animation. Topics may include visual perception, displays and framebuffers, image processing, affine and projective transformations, hierarchical modeling, hidden surface elimination, shading, ray-tracing, anti-aliasing, texture mapping, curves, surfaces, particle systems, dynamics, character animation, and animation principles.
#   - Prerequisites: CSE 333; CSE 332
# - [CSE 458: Computer Animation](http://courses.cs.washington.edu/courses/cse458/)
#   - Description: Introduction to basic principles of computer generated animation. Focus on the modeling and lighting of animated characters. Students from Art, CSE, and Music team up on projects to be built on commercially-available modeling and lighting packages.
#   - Prerequisites: CSE 457
# - [CSE 459: Animation Pre-Production](http://courses.cs.washington.edu/courses/cse459/)
#   -  Description: Pre-production of collaboratively designed animated shorts. In-depth analysis of classical and computer generated works. Character design and pre-planning, model sheets, character rigging, storyreel and animatics, character motion, design for multiple characters, and principles of animation as applied to character motion and effects.
#   - Prerequisites: CSE 458
# - [CSE 490 - Character Pre-Production for 3D Animation](https://courses.cs.washington.edu/courses/cse490j/18su/)
# - [CSE 464a - MASTERING FACIAL EXPRESSIONS IN CG](https://courses.cs.washington.edu/courses/cse464a/18su/)
# - [CSE 460: Animation Capstone](http://courses.cs.washington.edu/courses/cse460/)
#   - Description: Apply the knowledge gained in previous animation courses to produce a short animated film. Topics include scene planning, digital cinematography, creature and hard surface modeling, animatics and basics of character animation, and rendering techniques.
#   - Prerequisites: CSE 458; CSE 459
# - [CSE464: Advanced Topics in Digital Animation](http://courses.cs.washington.edu/courses/cse464/)
#   - Description: Students design individual animated works for professional quality demo reels. 2- and 3-D animatics, special effects design, advanced character animation techniques, 3-D paint techniques and integration, short design, sequence planning, non-photorealistic rendering options, interactive animation for pre-planning, and advanced production techniques and strategies.
#   - Prerequisite: CSE 458
# - [CSEP 557: Current Trends In Computer Graphics](http://courses.cs.washington.edu/courses/csep557/)
#   - Description: Introduction to computer image synthesis, modeling, and animation emphasizing the state-of-the-art algorithm applications. Topics may include visual perception, image processing, geometric transformations, hierarchical modeling, hidden-surface elimination, shading, ray-tracing, anti-aliasing, texture mapping, curves, surfaces, particle systems, dynamics, realistic character animation, and traditional animation principles.
#   - Prerequisite: CSE majors only.

# %% [markdown]
# Computer Science:
#
# - [Online Computer Science Courses](https://www.computerscience.org/resources/online-courses/)
# - [OSSU - Computer Science](https://github.com/ossu/computer-science)
# - [CS50: Introduction to Computer Science](https://www.edx.org/course/introduction-computer-science-harvardx-cs50x)
# - [Introduction to Computer Science and Programming Specialization](https://www.coursera.org/specializations/introduction-computer-science-programming?utm_source=gg&utm_medium=sem&utm_campaign=Deg-04-ComputerScience&Programming-UoL-US/UK&utm_content=DEGREE&Programming-UoL-US/UK&campaignid=2042754710&adgroupid=120976770713&device=c&keyword=&matchtype=&network=g&devicemodel=&adpostion=&creativeid=507142052850&hide_mobile_promo&gclid=CjwKCAiAsYyRBhACEiwAkJFKopFNN8x3A0i0F0Z7G1Kb78PFLiHQ0RhLPKaw17BnDZtqYsKS1TpYhRoCUAEQAvD_BwE#courses)
# - [Codecademy - Computer Science](https://www.codecademy.com/catalog/subject/computer-science?g_network=g&g_device=c&g_adid=494035656899&g_keyword=&g_acctid=243-039-7011&g_adtype=search&g_adgroupid=114763098457&g_keywordid=dsa-1147291854374&g_campaign=US+DSA+-+Subject&g_campaignid=12144922272&utm_id=t_dsa-1147291854374:ag_114763098457:cp_12144922272:n_g:d_c&utm_term=&utm_campaign=US%20DSA%3A%20Subject&utm_source=google&utm_medium=paid-search&utm_content=494035656899&hsa_acc=2430397011&hsa_cam=12144922272&hsa_grp=114763098457&hsa_ad=494035656899&hsa_src=g&hsa_tgt=dsa-1147291854374&hsa_kw=&hsa_mt=&hsa_net=adwords&hsa_ver=3&gclid=CjwKCAiAsYyRBhACEiwAkJFKounDMMi6PBSeUOSDOQzW3tUNBY5LTwfK437yHXoAMPCOTY6BzZE_LRoCB-8QAvD_BwE)
# - [Coursera - Software Engineering Courses](https://www.coursera.org/search?query=software%20engineering&)
# - [EdX - Computer Programming Courses](https://www.edx.org/learn/computer-programming)
# - [freeCodeCamp](https://www.freecodecamp.org/)
# - [Udacity - Client-Server Communication](https://www.udacity.com/course/client-server-communication--ud897)
# - [Authentication & Authorization: Oauth](https://www.udacity.com/course/authentication-authorization-oauth--ud330)
# - [Udacity - Compilers: Theory & Practice](https://www.udacity.com/course/compilers-theory-and-practice--ud168)
# - [Udacity - Shell Workshop](https://www.udacity.com/course/shell-workshop--ud206)
# - [Udacity - high Performance Computing](https://www.udacity.com/course/high-performance-computing--ud281)
# - [Coursera - Fundamentals of Computing Specialization](https://www.coursera.org/specializations/computer-fundamentals#courses)
# - [Coursera - IBM DevOps and Software Engineering Professional Certificate](https://www.coursera.org/professional-certificates/devops-and-software-engineering#courses)
# - [Coursera - Cloud Computing Specialization](https://www.coursera.org/specializations/cloud-computing)
# - [Coursera - Java Programming and Software Engineering Fundamentals Specialization](https://www.coursera.org/specializations/java-programming)
# - [Coursera - Software Design and Architecture Specialization](https://www.coursera.org/specializations/software-design-architecture) \*Needs Java

# %% [markdown]
# ## Data Analysis / Data Science

# %% [markdown]
# - **INSC 521: Database Design and Concepts**
#   - Description: The requirements capture, design, and development of relational database applications; analysis of business requirements and development of appropriate database systems.
#   - Alternatives:
#    - [Udacity - Database Systems Concepts & Design](https://www.udacity.com/course/database-systems-concepts-design--ud150)
#    - [Udacity - Intro to Relational Databases](https://www.udacity.com/course/intro-to-relational-databases--ud197)
# - **DAAN 825: Large-scale Database and Warehouse**
#   - Description: Examination of large-scale data storage technologies including NoSQL database systems for loosely-structured data, and warehouses for dimensional data.
#   - Prerequisite: INSC 521
#   - Alternatives:
# - **DAAN 826: Large-scale Databases for Real-Time Analysis**
#   - Description: This course provides an exploration of current and emerging big data solutions for handling large quantities of data in real-time. In particular, this course investigates methods to design, develop, and implement several systems used for real-time data analysis and storage such as document databases, column-based databases, queueing systems, and real-time processing systems.
#   - Prerequisite: DAAN 825
#   - Alternatives:
# - **SWENG 545: Data Mining**
#   - Description: Practical benefits of data mining will be presented; data warehousing, data cubes, and underlying algorithms used by data mining software.
#   - Alternatives:
#     - [Coursera - Data Mining](https://www.coursera.org/specializations/data-mining)
#     - [Coursera - Data Mining Foundations and Practice Specialization](https://www.coursera.org/specializations/data-mining-foundations-practice)
# - **DAAN 881: Data-Driven Decision Making**
#   - Description: Application and interpretation of analytics for real-life decision making.
#   - Prerequisite: STAT 500
#   - Alternatives:
# - **DAAN 822: Data Collection and Cleaning**
#   - Description: Tools and techniques required for data collection and computational procedures to automatically or semi-automatically identify and eliminate errors in large datasets.
#   - Prerequisite: STAT 500 and INSC 521
#   - Alternatives:
# - **A-I 801: Foundations of Artificial Intelligence**
#   - Description: Delivers an overview of AI, integrating relevant topics such as intelligent agents, knowledge and reasoning, reinforcement learning, planning and acting, belief networks, computational learning, Markov decision process, and more.
#   - Alternatives:
# - **DAAN 570: Deep Learning**
#   - Description: This course will cover the foundations on neural networks and deep learning networks. It covers the core concepts of deep neural networks, including the convolutional neural networks for image recognition, recurrent neural networks for sequence generation, and generative adversarial networks for image generation.
#   - Prerequisite: STAT 500
#   - Alternatives:
# - **DAAN 871: Data Visualization**
#   - Description: This course provides a foundation in the principles, concepts, techniques, and tools for visualizing large data sets.
#   - Alternatives:
#     - [Udacity - Data Visualization and D3.js](https://www.udacity.com/course/data-visualization-and-d3js--ud507)
#     - [Coursera - Data Visualization](https://www.coursera.org/learn/datavisualization)
#     - [Coursera - Foundamentals of Data Visualization](https://www.coursera.org/learn/fundamentals-of-data-visualization)
# - **DAAN 888: Design and Implementation of Analytics Systems**
#   - Description: Design and implement data science and analytics systems using contemporary tools and techniques. Choice of project topic mutually determined by student and instructor. Students must complete all core and required courses before enrolling.
#   - Prerequisite: IN SC 521, DAAN 825 and DAAN 881
#   - Alternatives:
# - **SWENG 505: Software Project Management**
#   - Description: Analysis and construction of project plans for the development of complex software products; how to manage change and cost control.
#   - Alternatives:
# - **A-I 574: Natural Language Processing**
#   - Description: This course covers basic as well as advanced concepts to gain a detailed understanding of Natural Language Processing tasks such as language modeling, text to speech generation, natural language understanding, and natural language generation. Students can learn the necessary skills to design a range of applications, including sentiment analysis, translating between languages, and answering questions. The practical implementation of these applications with deep neural networks is also discussed.
#   - Alternatives:
# - **A-I 879: Machine Vision**
#   - Description: This course focuses on the design of computer-based, machine vision systems using appropriate algorithms and best practices. Students will learn image representation and structuring; feature extraction and segmentation; and information extraction, filtering, and analysis.
#   - Alternatives:
# - **DAAN 862: Analytics Programming in Python**
#   - Description: This course will explore the development of analytics systems and the application of best practices and established software design principles using the Python programming language and its several toolkits.
#   - Alternatives:
# - **DAAN 572: Reinforcement Learning**
#   - Description: This course will cover the main theory and approaches of reinforcement learning, along with deep learning and common software libraries and packages.
#   - Alternatives:
# - **A-I 894: Research Topic**
#   - Description: The choice of project topic and exact form will be mutually determined by you and your instructor. A written paper based on the applied project is required and must contain project description, analysis, and interpretation of findings.
#   - Alternatives:

# %% [markdown]
# ## Technologies

# %% [markdown]
# - [Dask](https://dask.org/)
# - [TensorFlow Developer Professional Certificate](https://www.coursera.org/professional-certificates/tensorflow-in-practice?utm_source=deeplearning-ai&utm_medium=institutions&utm_campaign=TF2)
# - [TensorFlow: Data and Deployment Specialization](https://www.coursera.org/specializations/tensorflow-data-and-deployment)
# - [TensorFlow: Advanced Techniques Specialization](https://www.coursera.org/specializations/tensorflow-advanced-techniques)
# - [Jenkins](https://www.jenkins.io/)
# - [Docker](https://www.docker.com/)
#   - [What is a container?](https://www.docker.com/resources/what-container)
#   - [Documentation](https://docs.docker.com/)
#   - [Getting Started](https://www.docker.com/get-started)
# - [Kubernetes](https://kubernetes.io/)
#   - [Training](https://kubernetes.io/training/)
#   - [Documentation](https://kubernetes.io/docs/home/)
#     - [Tutorials: Learn the Basics](https://kubernetes.io/docs/tutorials/kubernetes-basics/)
#   - [EdX: Introduction to Kubernetes](https://www.edx.org/course/introduction-to-kubernetes)
#   - [Udacity - Scalable Microservices with Kubernetes](https://www.udacity.com/course/scalable-microservices-with-kubernetes--ud615)
# - [EdX: Introduction to Cloud Infrastructure Technologies](https://www.edx.org/course/introduction-to-cloud-infrastructure-technologies)
# - [EdX: Introduction to Linux](https://www.edx.org/course/introduction-to-linux)
# - Spark
#   - [Udacity - Spark](https://www.udacity.com/course/learn-spark-at-udacity--ud2002)
# - Apache Storm
#   - [Udacity - Real-Time Analytics with Apache Storm](https://www.udacity.com/course/real-time-analytics-with-apache-storm--ud381)
# - Hadoop
#   - [Intro to Hadoop and MapReduce](https://www.udacity.com/course/intro-to-hadoop-and-mapreduce--ud617)

# %% [markdown]
# ### Data engineering:
# - [Machine Learning Engineering for Production (MLOps) Specialization](https://www.coursera.org/specializations/machine-learning-engineering-for-production-mlops#courses)
# - [Start Data Engineering](https://www.startdataengineering.com/)
# - [Pluralsight: Data Engineering with AWS Machine Learning](https://www.pluralsight.com/courses/data-engineering-aws-machine-learning?aid=701j0000001heIoAAI&promo=&utm_source=non_branded&utm_medium=digital_paid_search_google&utm_campaign=US_Dynamic&utm_content=&cq_cmp=175953558&gclid=CjwKCAiA4veMBhAMEiwAU4XRr9aQnuP1Iy5Lv_pTyZOd7panN-uBtkxRMBhK8sIEhJwl-NERZNCJTRoCUrwQAvD_BwE)
# - [Coursera: Practical Data Science Specialization](https://www.coursera.org/specializations/practical-data-science)
# - [Coursera: Big Data Specialization](https://www.coursera.org/specializations/big-data)
# - [ACloudGuru: AWS Data Analytics - Specialty](https://learn.acloud.guru/course/312375cd-c136-4f1c-81dc-dbdcfff2d06b/overview)
# - [4 Best AWS Data Engineering Courses and Online Training](https://solutionsreview.com/data-integration/the-best-aws-data-engineering-courses/)
# - [The Art of Data Engineering pdf](https://databricks.com/wp-content/uploads/2021/11/The-Art-of-of-Data-Engineering-Ebook.pdf)
# - [Data Engineering Cookbook](https://cookbook.learndataengineering.com/docs/01-Introduction/)
# - [Youtube: data engineering with AWS](https://www.youtube.com/watch?v=0HGzfO7hseI)
# - [Youtube: data lakes and engineering on AWS](https://www.youtube.com/watch?v=hFSAxx_41Ug)
# - [Udacity: Data Engineering nanodegree](https://www.udacity.com/course/data-engineer-nanodegree--nd027?utm_source=gsem_generic&utm_medium=ads_n&utm_campaign=8016830296_c&utm_term=111649335010&utm_keyword=%2Bdata%20%2Bengineer%20%2Bcourse_b&gclid=CjwKCAiA4veMBhAMEiwAU4XRryK0J_ThkDYvKBQqJL4npHN41xV4t2dYB3HpyyW1vauW-qm4PD36_xoC7KoQAvD_BwE)
# - [Udemy: Learn AWS Data Engineering](https://www.udemy.com/course/learn-aws-data-engineering/)
# - [Cloud Academy: Data Engineer](https://cloudacademy.com/library/data-engineer/)
# - [Dataquest: Data Engineering career path](https://www.dataquest.io/path/data-engineering/)
# - [Simplilearn: Data Engineering bootcamp](https://www.simplilearn.com/pgp-data-engineering-certification-training-course?utm_source=google&utm_medium=cpc&utm_term=data%20engineer%20training&utm_content=11232365193-124891159160-522238963889&utm_device=c&utm_campaign=Search-DataCluster-PG-BigData-US-Main-AllDevice-adgroup-May18-2021-Data-Engineer-Training-Phrase&gclid=CjwKCAiA4veMBhAMEiwAU4XRrwo4AQ3UGlzUJg1A7bJfE4JEvpdhCCxmmaXk6q1AMn-sodunxyzKExoCzXwQAvD_BwE)
# - [A Beginner’s Guide to Data Engineering – Part 1](https://medium.com/@rchang/a-beginners-guide-to-data-engineering-part-i-4227c5c457d7)
# - [Moving from Pandas to Spark](https://towardsdatascience.com/moving-from-pandas-to-spark-7b0b7d956adb)
# - [10x faster Pandas Apply in a single line code change](https://towardsdatascience.com/10x-times-faster-pandas-apply-in-a-single-line-change-of-code-c42cb5e82f6d)
# - [Data Engineering Courses](https://www.mltut.com/best-data-engineering-courses-online/#3-become-a-data-engineer-coursera)
# - [9 Best Data Engineering Courses](https://digitaldefynd.com/best-data-engineering-courses/)
# - [Data Engineer Roadmap](https://github.com/datastacktv/data-engineer-roadmap)
# - [Data Engineer Roadmap for 2021](https://medium.com/coriers/data-engineering-roadmap-for-2021-eac7898f0641)
# - [Comprehensive List of Resources to becoming a Data Engineer](https://www.analyticsvidhya.com/blog/2018/11/data-engineer-comprehensive-list-resources-get-started/)
# - [A Complete Data Engineering Roadmap](https://medium.datadriveninvestor.com/data-engineering-roadmap-bbf4cc50b19d)
# - [Coursera - BI Foundations with SQL, ETL and Data Warehousing Specialization](https://www.coursera.org/specializations/bi-foundations-sql-etl-data-warehouse)
#
# ### Airflow:
# - [Datacamp](https://www.datacamp.com/courses/introduction-to-airflow-in-python?utm_source=adwords_ppc&utm_medium=cpc&utm_campaignid=12492439679&utm_adgroupid=133952950544&utm_device=c&utm_keyword=python%20airflow&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=545530787445&utm_targetid=aud-522010995285:kwd-1420538972094&utm_loc_interest_ms=&utm_loc_physical_ms=9052900&gclid=CjwKCAiAm7OMBhAQEiwArvGi3LUaaGNdY2jWazi8PrH-3Am-_D3LKrmYL8l_szp3xulDdc5Ivf_GyhoCRW0QAvD_BwE)
# - [Pluralsight: Productionalizing Data pipelines with Apache Airflow](https://www.pluralsight.com/courses/productionalizing-data-pipelines-apache-airflow)
# - [AWS Managed Workflows for Apache Airflow vs Glue](https://towardsdatascience.com/aws-managed-workflows-for-apache-airflow-vs-glue-2cce07aacf6a)
# - [Getting Started using Airflow with Docker](http://www.marknagelberg.com/getting-started-with-airflow-using-docker/)
# - [Using Airflow to Execute SQL](https://www.astronomer.io/guides/airflow-sql-tutorial/)
# - [Running Airflow in Docker](https://airflow.apache.org/docs/apache-airflow/stable/start/docker.html)
#
# Migrating to v2.X
# - [Airflow: Upgrading from 1.10 to 2](https://airflow.apache.org/docs/apache-airflow/stable/upgrading-from-1-10/index.html)
# - [puckel github](https://github.com/puckel/docker-airflow)
# - [puckel github: Update to Airflow 2.0.0](https://github.com/puckel/docker-airflow/pull/618)
#
# ### AWS/Cloud:
#
# - [Pluralsight: Processing Data on AWS](https://www.pluralsight.com/courses/processing-data-aws?exp=3)
# - [Pluralsight: Streaming with AWS Kinesis](https://www.pluralsight.com/courses/developing-stream-processing-applications-aws-kinesis?exp=3)
# - [Coursera: Cloud Computing at Scale Specialization](https://www.coursera.org/specializations/building-cloud-computing-solutions-at-scale)
# - [Approaches to Workflows in AWS](https://www.phdata.io/blog/approaches-to-workflow-in-aws/)
# - [Pipeline stuff on AWS](https://aws.amazon.com/blogs/big-data/building-complex-workflows-with-amazon-mwaa-aws-step-functions-aws-glue-and-amazon-emr/)
#
# ### Data Science:
#
# - [Github: Open Source Society University](https://github.com/ossu/data-science)
# - [Github: academic/awesome-datascience](https://github.com/academic/awesome-datascience)
# - [Top 10 Popular GitHub Repos to learn about DS](https://towardsdatascience.com/top-10-popular-github-repositories-to-learn-about-data-science-4acc7b99c44)
# - [7 best Github repos for leavning DS](https://medium.com/pythoneers/7-best-github-repositories-for-learning-data-science-b9911199a7b7)
# - [Udacity: Free courses](https://www.udacity.com/courses/all?field=school-of-data-science&field=school-of-cloud-computing&price=Free)
# - [SQLAlchemy](https://www.sqlalchemy.org/)
# - [Python docs: Virtual environments and packages](https://docs.python.org/3/tutorial/venv.html)
# - [Python docs: Creation of virtual environments](https://docs.python.org/3/library/venv.html)
# - [Python docs: Installing packages using pip and virtual environments](https://packaging.python.org/en/latest/guides/installing-using-pip-and-virtual-environments/)
# - [ACloudGuru: Elastic Stack Essentials](https://learn.acloud.guru/course/c867719d-0716-41d9-a0eb-81e6e1dd3a7a/overview)
# - [ACloudGuru: Elasticsearch Deep Dive](https://learn.acloud.guru/course/1e3ff00e-95bf-451b-be04-44d4bce6bfba/overview)
# - [ACloudGuru: Elastic Certified Analyst Exam prep](https://learn.acloud.guru/course/acgs-elastic-certified-analyst-exam-preparation-course/overview)
# - [ACloudGuru: Elastic Certification Prep Course](https://learn.acloud.guru/course/0f5be9b6-23f3-4d29-ba27-d5b7d0923faa/overview)
# - [ACloudGuru: Containers Learning Path](https://learn.acloud.guru/learning-path/cloud-adjacent-containers)
# - [Machine Learning](https://www.coursera.org/learn/machine-learning)
# - [Deep Learning Specialization](https://www.coursera.org/specializations/deep-learning#courses)
# - [Natural Language Processing Specialization](https://www.coursera.org/specializations/natural-language-processing#courses)
# - [Jesse Spencer-Smith: Matching Data Science Organizational Maturity to Data Science Skills to Optimially Grow Your Team](https://on-demand.gputechconf.com/gtc/2018/presentation/s8954-matching-ds-organizational-maturity-to-ds-skills-to-optimally-grow-your-team.pdf)
# - [Computational and Inferential Thinking: The Foundations of Data Science](https://inferentialthinking.com/chapters/intro.html)

# %% [markdown]
# ### Environmental:
#
# - [Youtube: astrum](https://www.youtube.com/c/astrumspace/videos)
# - [Github: #Oceanography topic](https://github.com/topics/oceanography)
# - [Github: #physical-oceanography topic](https://github.com/topics/physical-oceanography)
# - [Github: #earth-science topic](https://github.com/topics/earth-science)
# - [Github: #sustainability topic](https://github.com/topics/sustainability)
# - [Github: Project Ocean](https://github.com/google/project-OCEAN)
# - [Github: Intro to Physical Oceanography](https://github.com/rabernat/intro_to_physical_oceanography)
# - [Github: physical oceanography](https://github.com/kkats/physical-oceanography)
# - [Github: Oceanography](https://github.com/hafez-ahmad/Oceanography)
# - [Github: EarthML](https://github.com/pyviz-topics/EarthML)
# - [Earth Lab: Free online courses, tutorials and tools](https://www.earthdatascience.org/)
# - [Earth Lab: Earth Data Analytics Online Certificate](https://www.earthdatascience.org/courses/intro-to-earth-data-science/git-github/github-collaboration/)
# - [Github: Earth Lab](https://github.com/earthlab)
# - [Github: earth-analytics-intro-to-earth-data-science-textbook](https://github.com/earthlab/earth-analytics-intro-to-earth-data-science-textbook)
# - [Earth Lab: Earth Data Science Corps](https://earthlab.colorado.edu/our-work/teaching-and-learning-earth-data-science/earth-data-science-corps)
# - [Github: Awesome Earth AI](https://github.com/ESIPFed/Awesome-Earth-Artificial-Intelligence)
# - [An Introduction to Earth and Environmental Data Science online textbook](https://earth-env-data-science.github.io/intro.html)
# - [Github: earth-env-data-science-book](https://github.com/earth-env-data-science/earth-env-data-science-book)
# - [Github: ENVT3065 sustainability and challenges](https://github.com/jonathandumas/ENVT3065-sustainability-and-challenges)
#
# ### Ecology:
#
# - [Water: Science and Society](https://www.e-education.psu.edu/earth111/node/1013)
# - [PSU World Campus: Bachelor of Science in Software Engineering](https://www.worldcampus.psu.edu/degrees-and-certificates/penn-state-online-software-engineering-bachelors-degree/overview)
# - [PSU World Campus: Data Analytics Masters](https://www.worldcampus.psu.edu/degrees-and-certificates/data-analytics-base/courses)
# - [PSU World Campus: Artificial Intelligence Masters](https://www.worldcampus.psu.edu/degrees-and-certificates/penn-state-online-artificial-intelligence-masters-degree/courses)
# - [Penn State ROAM courses](https://roam.libraries.psu.edu/courses)
# - [PSU World Campus: Geographic Information Systems (GIS) Masters](https://www.worldcampus.psu.edu/degrees-and-certificates/geographic-information-systems-gis-masters/courses)
# - [PSU World Campus: Spatial Data Science](https://www.worldcampus.psu.edu/degrees-and-certificates/penn-state-online-spatial-data-science-masters-degree/overview)
# - [PSU World Campus: Renewable Energy and Sustainability Systems Masters](https://www.worldcampus.psu.edu/degrees-and-certificates/renewable-energy-and-sustainability-systems/overview)
# - [PSU World Campus: Weather and Climate Analytics Graduate Certificate](https://www.worldcampus.psu.edu/degrees-and-certificates/penn-state-online-weather-and-climate-analytics-certificate/overview)
# - [Oxford Department of Zoology](https://www.zoo.ox.ac.uk/ecology-and-conservation)
# - [University of Cambridge Application of Artificial Intelligence to the study of Environmental Risks](https://www.postgraduate.study.cam.ac.uk/courses/directory/eaespdaai)

# %% [markdown]
# ## Other
# - [Green Tea press – online books](https://greenteapress.com/wp/)
# - [The Programmatic Bookshelf](https://pragprog.com/titles/)
# - [Sofware engineering fundamentals for Data Scientists – Kdnuggets](https://www.kdnuggets.com/2020/06/software-engineering-fundamentals-data-scientists.html)
# - [Berkeley Extension: Introduction to Computers and Programming](https://extension.berkeley.edu/search/publicCourseSearchDetails.do?method=load&courseId=14201621)

# %% [markdown]
# - [ ] (for unchecked checkbox)
# - [x] (for checked checkbox)
# - [ ] (~~for strikethrough text~~)

# %% [markdown]
# &check; - html checkbox example
#
# :white_check_mark: - emoji checkbox example - only works if application can use emoji shortnames
#
# &#9746; - unicode checkbox example
