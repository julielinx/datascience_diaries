# %% [markdown]
# # CSE 142: Computer Programming I

# %% [markdown]
# - [CSE 142 Main Page](http://courses.cs.washington.edu/courses/cse142/)
# - [CSE 142 Spring 2022](https://courses.cs.washington.edu/courses/cse142/22sp/index.shtml)
# - [Syllabus](https://courses.cs.washington.edu/courses/cse142/22sp/handouts/01.pdf)
# - [Calendar](https://courses.cs.washington.edu/courses/cse142/22sp/calendar.shtml)
# - [Homework](https://courses.cs.washington.edu/courses/cse142/22sp/homework.shtml)
# - [Handouts](https://courses.cs.washington.edu/courses/cse142/22sp/handouts.shtml)
# - [Discussion Section](https://courses.cs.washington.edu/courses/cse142/22sp/sections.shtml)
# - [Textbook](https://courses.cs.washington.edu/courses/cse142/22sp/textbook.shtml)

# %% [markdown]
# ## Calendar

# %% [markdown]
# - Class 1 (3/28)
#     - [] Read chapter(s): 1.1-1.3
#     - [x] Watch lecture 1
#     - [x] Review slides
# - Class 2 (3/30)
#     - [] Read chapter(s): 1.4-1.5
#     - [x] Watch lecture 2
#     - [x] Replicate lecture "figure" example
#     - [x] Review slides
#     - [x] Video: methods
#     - [x] Homework 1: Song
#     - [x] Lab Section Work 1
# - Class 3 (4/1)
#     - [] Read chapter(s): 2.1-2.2
#     - [x] Watch lecture 3
#     - [x] Review slides
#     - [x] Video: expressions
#     - [x] Video: variables/assignment
# - Class 4 (4/4)
#     - [] Read chapter(s): 2.3
#     - [x] Watch lecture 4
#     - [x] Review slides
#     - [x] Video: for loop
#     - [x] Video: nested loops
# - Class 5 (4/6)
#     - [] Read chapter(s): 2.4-2.5
#     - [x] Watch lecture 5
#     - [x] Review slides
#     - [x] Video: complex figure
#     - [x] Lab Section Work 2
#     - [x] Homework 2: Rocket Ship
# - Class 6 (4/8)
#     - [] Read chapter(s): 3.1
#     - [x] Watch lecture 6
#     - [x] Review slides
#     - [x] Video: parameter mystery
# - Class 7 (4/11)
#     - [] Read chapter(s): Supplement 3G
#     - [x] Watch lecture 7
#     - [x] Review slides
#     - [x] Video: basic drawing
#     - [x] Lab Section Work 3
# - Class 8 (4/13)
#     - [] Read chapter(s): Supplement 3G
#     - [x] Watch lecture 8
#     - [x] Video: parameterized drawing
#     - [x] Homework 3: Cafe Wall
# - Class 9 (4/15)
#     - [] Read chapter(s): 3.2
#     - [x] Watch lecture 9
#     - [x] Review slides
#     - [x] Video: parameters & return values
#     - [x] Diagram: information flow
#     - [x] Link: Boeing integer overflow bug
#     - [x] Link: wikipedia integer overflow description
# - Class 10 (4/18)
#     - [] Read chapter(s): 3.3-3.4, 4.1-4.2
#     - [x] Watch lecture 10
#     - [x] Review slides
#     - [x] Video: scanner
#     - [x] Video: cumulative sum

# %% [markdown]
# ### To Do
#
# - Class 11 (4/20)
#     - [] Read chapter(s): 4.4-4.5
#     - [x] Watch lecture 11
#     - [x] Review slides
#     - [x] Video: nested if/else
#     - [x] Video: factoring if/else
#     - [x] Lab Section Work 4
# - Class 12 (4/22)
#     - [] Read chapter(s): 3.3, 4.3
#     - [x] Watch lecture 12
#     - [] Review slides
#     - [] Video: strings
#     - [] Link: Robin Dunbar on Shakespeare
# - Class 13 (4/25)
#     - [] Read chapter(s): 5.1-5.2
#     - [] Watch lecture 13
#     - [] Review slides
#     - [] Video: sentinel loops
#     - [] Link: zune bug
# - Class 14 (4/27)
#     - [] Read chapter(s): 5.1
#     - [] Watch lecture 14
#     - [] Review slides
#     - [] Video: random numbers
#     - [] Lab Section Work 5
# - Class 15 (4/29)
#     - [] Read chapter(s): 5.5
#     - [] Watch lecture 15
#     - [] Review slides
#     - [] Video: assertions
#     - [] Handout: assertion problems
# - Class 16 (5/2)
#     - [] Read chapter(s): 5.3
#     - [] Watch lecture 16
#     - [] Review slides
#     - [] Video: type boolean
#     - [] Problems: Methods.java
# - Class 17 (5/4)
#     - [] Read chapter(s): 6.1-6.2, 5.4
#     - [] Watch lecture 17
#     - [] Review slides
#     - [] Video: token-based processing
#     - [] Mid-term sample test
#     - [] Lab Section Work Mid-term
# - Class 18 (5/9)
#     - [] Read chapter(s): 6.3-6.5
#     - [] Watch lecture 18
#     - [] Review slides
#     - [] Video: line-based processing
#     - [] Video: complex input
# - Class 19 (5/11)
#     - [] Read chapter(s): 7.1
#     - [] Watch lecture 19
#     - [] Review slides
#     - [] Lab Section Work 6
# - Class 20 (5/13)
#     - [] Read chapter(s): 7.2
#     - [] Watch lecture 20
#     - [] Review slides
#     - [] Video: array mystery
#     - [] Video: array traversal
# - Class 21 (5/16)
#     - [] Read chapter(s): 7.4, 7.6
#     - [] Watch lecture 21
#     - [] Review slides
#     - [] Video: array tallying
# - Class 22 (5/18)
#     - [] Read chapter(s): 7.3, 8.1-8.2
#     - [] Watch lecture 22
#     - [] Review slides
#     - [] Video: defining a class
#     - [] Lab Section Work 7
# - Class 23 (5/20)
#     - [] Read chapter(s): 8.3-8.4
#     - [] Watch lecture 23
#     - [] Review slides
#     - [] Video: constructors
#     - [] Video: encapsulation
# - Class 24 (5/23)
#     - [] Watch lecture 24
#     - [] Resources: ass8.zip
# - Class 25 (5/25)
#     - [] Read chapter(s): 9.1,9.3
#     - [] Watch lecture 25
#     - [] Review slides
#     - [] Video: inheritance
#     - [] Lab Section Work 8
# - Class 26 (5/27)
#     - [] Read chapter(s): 10.1
#     - [] Watch lecture 26
#     - [] Review slides
#     - [] Video: arraylist example
#     - [] Handout: arraylist problems
# - Class 27 (6/1)
#     - [] Watch lecture 27
#     - [] Video: array shifting
#     - [] Lab Section Work 9
# - Class 28 (6/3)
#     - [] Watch lecture 28
#     - [] critter tournament?
