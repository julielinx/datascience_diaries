# %% [markdown]
# # Penn State GIS courses

# %% [markdown]
# ## Courses in GIS program
#
# - [GEOG 482: Making Maps that Matter](https://roam.libraries.psu.edu/node/1298)
#     - [youtube playlist](https://www.youtube.com/playlist?list=PL2fx_1KBatEI7sSpHzBPK4JvFVjYNwYgm)
# - [GEOG 480: Exploring Imagery and Elevation Data in GIS Applications](https://roam.libraries.psu.edu/node/1343)
#     - [Lesson page](https://www.e-education.psu.edu/geog480/node/11)
#     - Prerequisites: GEOG 482 or equivalent professional experience
# - [GEOG 481: Topographic Mapping with Lidar](e-education.psu.edu/geog481/resources/l1.html)
#     - Lessons only available through paid online campus
# - [GEOG 483: Problem Solving with GIS](https://www.e-education.psu.edu/geog483/node/1770)
#     - Lessons only available through paid online campus
# - [GEOG 484: GIS Database Development](https://www.e-education.psu.edu/geog484/node/1776)
#     - Prerequisite: GEOG 483 or equivalent experience
#     - Lessons only available through paid online campus
# - [GEOG 485: GIS Programming and Software Development](https://roam.libraries.psu.edu/node/1340)
#     - [Lessons page](https://www.e-education.psu.edu/geog485/node/91)
#     - Prerequisite: GEOG 484 or equivalent experience
# - [GEOG 486: Cartography and Visualization](https://roam.libraries.psu.edu/node/1299)
#     - [Lesson page](https://www.e-education.psu.edu/geog486/)
#     - Prerequisites: GEOG 484
# - [GEOG 487: Environmental Challenges in Spatial Data Science](https://roam.libraries.psu.edu/node/1341)
#     - [Lesson page](https://www.e-education.psu.edu/geog487/node/11)
#     - Prerequisites
#         - GEOG 483: Problem Solving with GIS
#         - GEOG 484: GIS Database Development or equivalent experience
# - [GEOG 489: Advanced Python Programming for GIS](https://roam.libraries.psu.edu/node/1342)
#     - [Lesson page](https://www.e-education.psu.edu/geog489/node/1776)
#     - Prerequisite: GEOG 485
# - [GEOG 585: Open Web Mapping](https://roam.libraries.psu.edu/node/1337)
#     - [Lesson page](https://www.e-education.psu.edu/geog585/node/508)
#     - Prerequisites: GEOG 485 GIS Programming and Automation
# - [GEOG 863: Web Application Development for the Geospatial Professional](https://roam.libraries.psu.edu/node/1352)
#     - [Lesson page](https://www.e-education.psu.edu/geog863/node/1776)
#     - Prerequisites: GEOG 485 or other experience in computer programming
# - [GEOG 583: Geospatial System Analysis and Design](https://roam.libraries.psu.edu/node/1344)
#     - [Lesson page](https://www.e-education.psu.edu/geog583/node/25)
#     - Prerequisite: GEOG 484
# - [GEOG 586: Geographic Information Analysis](https://roam.libraries.psu.edu/node/1346)
#     - [Lesson page](https://www.e-education.psu.edu/geog586/node/508)
#     - Prerequisite: GEOG 485 or GEOG 486 or GEOG 487 or equivalent experience
# - [GEODZ 511: Geodesign History, Theory, Principles](https://roam.libraries.psu.edu/node/1459)
#     - [Lesson page](https://oer.hax.psu.edu/rmw175/sites/geodz511/)
# - [GEOG 597: Challenges in Global Geospatial Analytics](https://roam.libraries.psu.edu/node/1376)
#     - [Lesson page](https://www.e-education.psu.edu/geog597g/)
# - [GEOG 858: Spatial Data Science for Emergency Management](https://roam.libraries.psu.edu/node/1347)
#     - [Lesson page](https://www.e-education.psu.edu/geog858/)
#     - Prerequisite: Geography 483: Problem Solving with GIS
# - [GEOG 871: Geospatial Technology Project Management](https://roam.libraries.psu.edu/node/1345)
#     - [Lesson page](https://www.e-education.psu.edu/geog871/node/1699)
# - [GEOG 892: Unmanned Aerial Systems](https://roam.libraries.psu.edu/node/1418)
#     - [Lesson page](https://www.e-education.psu.edu/geog892/node/508)
#     - Prerequisites: working knowledge of the following topics, covered in Geog 480, 482, 483:
#         - photogrammetry and geographic information system (GIS)
#         - basic GIS or CAD data processing experience
#         - datums and coordinate systems
#         - maps accuracy standard
# - [GEOG 885: Advanced Analytic Methods in Geospatial Intelligence](https://roam.libraries.psu.edu/node/1355)
#     - [Lesson page](https://www.e-education.psu.edu/geog885/node/1776)
#     - Prerequisite: GEOG 882: Geographic Foundations of Geospatial Intelligence
# - [GEOG 882: Geographic Foundations of Geospatial Intelligence](https://roam.libraries.psu.edu/node/1353)
#     - [Lesson page](https://www.e-education.psu.edu/geog882/node/1952)
#     - GEOG 882 is a required first course in the Certificate Program in Geospatial Intelligence
# - [GEOG 855: Spatial Data Analytics for Transportation](https://roam.libraries.psu.edu/node/1365)
#     - [Lesson page](https://www.e-education.psu.edu/geog855/node/508)
# - [GEOG 868: Spatial Database Management](https://roam.libraries.psu.edu/node/1357)
#     - [Lesson page](https://www.e-education.psu.edu/spatialdb/node/1776)
#     - Prerequisites: GEOG 484 or equivalent experience
# - [GEOG 865: Cloud and Server GIS](https://roam.libraries.psu.edu/node/1356)
#     - [Lesson page](https://www.e-education.psu.edu/geog865/node/25)
# - [GEOG 850: Location Intelligence for Business](https://roam.libraries.psu.edu/node/1367)
#     - [Lesson page](https://www.e-education.psu.edu/geog850/node/11)
# - [GEOG 487: Environmental Challenges in Spatial Data Science](https://roam.libraries.psu.edu/node/1341)
#     - [Lesson page](https://www.e-education.psu.edu/geog487/node/11)
#     - Prerequisites
#         - GEOG 483: Problem Solving with GIS
#         - GEOG 484: GIS Database Development or equivalent experience

# %% [markdown]
# ## Other Courses
#
# - [GEOG 160: Mapping Our Changing World](https://roam.libraries.psu.edu/node/1417)
#     - [Lesson page](https://www.e-education.psu.edu/geog160/)
# - [The Nature of Geographic Information](https://roam.libraries.psu.edu/node/1461)
#     - [Online book](https://www.e-education.psu.edu/natureofgeoinfo/)
# - [Maps and the Geospatial Revolution](https://roam.libraries.psu.edu/node/1375)
#     - [Lesson page](https://www.e-education.psu.edu/maps/)
# - [Geospatial Intelligence and the Geospatial Revolution](https://roam.libraries.psu.edu/node/1374)
#     - [Lesson page](https://www.e-education.psu.edu/geointmooc/)
# - [EARTH 801: Computation and Visualization in the Earth Sciences](https://roam.libraries.psu.edu/node/1360)
#     - [Lesson page](https://www.e-education.psu.edu/earth801/)
#     - Prerequisites: None
# - [EARTH 501: Controversies in the Earth Sciences](https://roam.libraries.psu.edu/node/1330)
#     - [Lesson page](https://www.e-education.psu.edu/earth501/)
#     - Prerequisites: None
# - [EARTH 520: Plate Tectonics and People: Foundations of Solid Earth Science](https://roam.libraries.psu.edu/node/1331)
#     - [Lesson page](https://www.e-education.psu.edu/earth520/)
#     - Prerequisites: None
# - [PNG 550: Reactive Transport in the Subsurface](https://roam.libraries.psu.edu/node/1433)
#     - [Lesson page](https://www.e-education.psu.edu/png550/)
# - [EME 807: Technologies for Sustainability Systems](https://roam.libraries.psu.edu/node/1309)
#     - [Lesson page](https://www.e-education.psu.edu/eme807/)
# - [EARTH 111N: Water: Science and Society](https://roam.libraries.psu.edu/node/1368)
#     - [Lesson page](https://www.e-education.psu.edu/earth111/)
# - [METEO 3: Introductory Meteorology](https://roam.libraries.psu.edu/node/1448)
#     - [Lesson page](https://www.e-education.psu.edu/meteo3/)
# - [EARTH 107N: Coastal Processes, Hazards and Society](https://roam.libraries.psu.edu/node/1369)
#     - [Lesson page](https://www.e-education.psu.edu/earth107/)
# - [EARTH 103N: Earth in the Future](https://roam.libraries.psu.edu/node/1313)
#     - [Lesson page](https://www.e-education.psu.edu/earth103/)
#     - Prerequisites: None
# - [EARTH 530: Earth Surface Processes in the Critical Zone](https://roam.libraries.psu.edu/node/1332)
#     - [Lesson page](https://www.e-education.psu.edu/earth530/)
#     - Prerequisites: None
# - [GEOG 469: Energy Industry Applications of GIS](https://roam.libraries.psu.edu/node/1319)
#     - [Lesson page](https://www.e-education.psu.edu/geog469/)
# - [EARTH 540: Essentials of Oceanography](https://roam.libraries.psu.edu/node/1333)
#     - [Lesson page](https://www.e-education.psu.edu/earth540/)
#     - Prerequisite: EARTH 501
# - [EME 504: Foundations in Sustainability Systems](https://roam.libraries.psu.edu/node/1301)
#     - [Lesson page](https://www.e-education.psu.edu/eme504/)
#     - Prerequisites: None
# - [METEO 469: From Meteorology to Mitigation: Understanding Global Warming](https://roam.libraries.psu.edu/node/1336)
#     - [Lesson page](https://www.e-education.psu.edu/meteo469/)
# - [METEO 300: Fundamentals of Atmospheric Science](https://roam.libraries.psu.edu/node/1362)
#     - [Lesson page](https://www.e-education.psu.edu/meteo300/)
#     - Prerequisites: physics
# - [GEOG 431: Geography of Water Resources](https://roam.libraries.psu.edu/node/1364)
#     - [Lesson page](https://www.e-education.psu.edu/geog431/)
# - [GEOG 468: GIS Analysis and Design](https://roam.libraries.psu.edu/node/1426)
#     - [Lesson page](https://www.e-education.psu.edu/geog468/)
#     - Prerequisites: None
# - [How We Got from There to Here: A Story of Real Analysis](https://roam.libraries.psu.edu/node/1508)
#     - [Online booi](https://knightscholar.geneseo.edu/cgi/viewcontent.cgi?article=1019&context=oer-ost)
