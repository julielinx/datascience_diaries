# %% [markdown]
# # UW CSE 311: [Foundations of Computing I](https://courses.cs.washington.edu/courses/cse311/)

# %% [markdown]
# - [CSE 311](https://courses.cs.washington.edu/courses/cse311/21au/index.html)
# - [Calendar](https://courses.cs.washington.edu/courses/cse311/21au/calendar/calendar.html)
# - [Lectures](https://courses.cs.washington.edu/courses/cse311/21au/calendar/lecturelist.html)
# - [Sectionals](https://courses.cs.washington.edu/courses/cse311/21au/calendar/sectionlist.html)
# - [Assignments/homework](https://courses.cs.washington.edu/courses/cse311/21au/calendar/hwlist.html)
# - Optional Textbook: Discrete Mathematics and Its Applications by Kenneth Rosen

# %% [markdown]
# ## Schedule
#
# - September 29
#   - [ ] [L1: Introduction and Propositional Logic](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture01-logic.pdf)
#   - [ ] Rosen 1.1
#   - [ ] Section 1: Propositional Logic
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section01.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section01-solutions.pdf)
# - October 1
#   - [ ] [L2: Translation and Circuits](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture02-circuits-equivalences.pdf)
#   - [ ] Rosen 11.3
# - October 4
#   - [ ] [L3: Equivalences](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture03-equivalences.pdf)
#   - [ ] Rosen 1.2
# - October 6
#   - [ ] [L4: Boolean Algebra](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture04-booleanalgebra.pdf)
#   - [ ] Rosen 11.1
#   - [ ] Section 2: Equivalences
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section02.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section02-solutions.pdf)
# - October 8
#   - [ ] [L5: Canonical Forms](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture05-canonicalforms.pdf)
#   - [ ] Rosen 11.2
#   - [ ] [Homework 1](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework01.pdf) due
# - October 11
#   - [ ] [L6: Predicate Logic](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture06-fol.pdf)
#   - [ ] Rosen 1.3-1.4
# - October 13
#   - [ ] [L7: Proofs for Propositional Logic](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture07-inference.pdf)
#   - [ ] Rosen 1.5
#   - [ ] Section 3: Predicate Logic and Inference
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section03.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section03-solutions.pdf)
# - October 15
#   - [ ] [L8: Proofs for Predicate Logic](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture08-moreproofs.pdf)
#   - [ ] Rosen 1.5
#   - [ ] [Homework 2](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework02.pdf) due
# - October 18
#   - [ ] [L9: English Proofs](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture09-englishproofs.pdf)
#   - [ ] Rosen 1.6-1.7
# - October 20
#   - [ ] [L10: Set Theory](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture10-sets.pdf)
#   - [ ] Rosen 2.1-2.3
#   - [ ] Section 4: English Proofs and Set Theory
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section04.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section04-solutions.pdf)
# - October 22
#   - [ ] [L11: Sets and Modular Arithmetic](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture11-setsmod.pdf)
#   - [ ] Rosen 3.4
#   - [ ] [Homework 3](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework03.pdf) due
# - October 25
#   - [ ] [L12: Modular Arithmetic and Applications](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture12-numbertheory.pdf)
#   - [ ] Rosen 3.4
# - October 27
#   - [ ] [L13: Primes and GCD](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture13-primesgcd.pdf)
#   - [ ] Rosen 3.5
#   - [ ] Section 5: Number Theory
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section05.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section05-solutions.pdf)
# - October 29
#   - [ ] [L14: Euclidian Algorithm and Modular Equations](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture14-modinvexp.pdf)
#   - [ ] Rosen p.277-9, p.231-5, p.226-7
#   - [ ] [Homework 4](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework04.pdf) due
# - November 1
#   - [ ] [L15: Modular Exponentiation and Induction](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture15-induction.pdf)
#   - [ ] Rosen 4.1
# - November 3
#   - [ ] [L16: Strong Induction](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture16-stronginduction.pdf)
#   - [ ] Rosen 4.2
#   - [ ] Section 6: Induction
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section06.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section06-solutions.pdf)
# - November 5
#   - [ ] [L17: Recursively Defined Functions](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture17-recursivedefs.pdf)
#   - [ ] Rosen 4.3
#   - [ ] [Homework 5](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework05.pdf) due
# - November 8
#   - [ ] [L18: Recursively Defined Sets and Structural Induction](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture18-recursivesets.pdf)
#   - [ ] Rosen 4.3
# - November 10
#   - [ ] [L19: More Structural Induction](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture19-structuralinduction.pdf)
#   - [ ] Rosen 4.3
# - November 15
#   - [ ] [L20: Regular Expressions (REs)](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture20-res.pdf)
#   - [ ] Rosen p.817-819
# - November 17
#   - [ ] [L21: Context-Free Grammars (CFGs)](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture21-cfgs.pdf)
#   - [ ] Rosen 8.1, p.541-548
#   - [ ] Section 7: Strong Induction, REs, and CFGs
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section07.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section07-solutions.pdf)
# - November 19
#   - [ ] [L22: Relations and Directed Graphs](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture22-relations.pdf)
#   - [ ] Rosen 8.1, p.541-548
# - November 22
#   - [ ] [L23: Finite State Machines (FSMs)](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture23-dfas.pdf)
#   - [ ] [Homework 6](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework06.pdf) due
# - November 29
#   - [ ] [L24: FSM Minimization and NFAs](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture24-fsmoutput.pdf)
# - December 1
#   - [ ] [L25: Relating DFAs, NFAs, and REs](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture25-nfas.pdf)
#   - [ ] Section 8: Relations and DFAs
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section08.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section08-solutions.pdf)
# - December 3
#   - [ ] [L26: Limitations of DFAs, NFAs, and REs](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture26-irregularity.pdf)
#   - [ ] [Homework 7](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework07.pdf) due
# - December 6
#   - [ ] [L27: Cardinality and Uncomputability](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture27-cardinality.pdf)
# - December 8
#   - [ ] [L28: Undecidability of the Halting Problem](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture28-halting.pdf)
#   - [ ] Section 9: Irregularity and Cardinality
#     - [Problems](https://courses.cs.washington.edu/courses/cse311/21au/sections/section09.pdf)
#     - [Solutions](https://courses.cs.washington.edu/courses/cse311/21au/sections/section09-solutions.pdf)
# - December 10
#   - [ ] [L20: Reductions and Turing Machines](https://courses.cs.washington.edu/courses/cse311/21au/lectures/lecture29-tms.pdf)
#   - [ ] [Homework 8](https://courses.cs.washington.edu/courses/cse311/21au/hws/homework08.pdf) due
