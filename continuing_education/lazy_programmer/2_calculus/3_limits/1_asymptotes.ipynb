# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-50, 50, 1000)
y = np.sin(x)/x
plt.plot(x, y)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');

# %%
plt.x

# %%
y1 = 1/x
plt.plot(x, y1)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k')
plt.xlim(-10, 10),
plt.ylim(-10, 10);

# %%
y2 = x / (x -1)
plt.plot(x, y2)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k')
plt.xlim(-10, 10),
plt.ylim(-10, 10);

# %%
y3 = np.log2(x)
plt.plot(x, y3)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');
# Out:
# <ipython-input-21-ed58d38698c0>:1: RuntimeWarning: invalid value encountered in log2
#   y3 = np.log2(x)

# %%
y4 = np.log10(x)
plt.plot(x, y4)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');
# Out:
# <ipython-input-24-e4346411cf97>:1: RuntimeWarning: invalid value encountered in log10
#   y4 = np.log10(x)

# %%
y5 = np.exp(x)
plt.plot(x, y5)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k')
plt.xlim(-5, 5)
plt.ylim(0, 5);

# %%
x1 = np.linspace(-5, 5, 1000)
y5 = np.e ** x1
plt.plot(x1, y5)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k')
plt.ylim(0, 10);

# %%
0 * 5
# Out:
# 0

# %%
y6 = 2/x
plt.plot(x, y6)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k')
plt.xlim(-10, 10)
plt.ylim(-10, 10);

# %%
y7 = 2*x**2 + 5*x + 3
plt.plot(x, y7)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');

# %%
y8 = 3*x**2 - 7*x + 9
plt.plot(x, y8)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');

# %%
y9 = (2*x**2 + 5*x + 3) / (3*x**2 - 7*x + 9)
plt.plot(x, y9)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');

# %%
y9 = (2*x**2 + 5*x + 3) / (3*x**2 - 7*x + 9)
plt.plot(x, y9)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k')
plt.xlim(-5, 5);

# %%
y10 = (2*x**2 + 5*x + 3) / (3*x**4 - 7*x + 9)
plt.plot(x, y10)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');

# %%
y10 = (2*x**2 + 5*x + 3) / (3*x**4 - 7*x + 9)
plt.plot(x, y10)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k')
plt.xlim(-15, 15);

# %%
y11 = (2*x**4 + 5*x + 3) / (3*x**2 - 7*x + 9)
plt.plot(x, y11)
plt.axhline(y=0, c='k')
plt.axvline(x=0, c='k');
