# %%
import numpy as np
import pandas as pd

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.ones((2,3))*10
# Out:
# array([[10., 10., 10.],
#        [10., 10., 10.]])

# %%
np.diag((3,3))
# Out:
# array([[3, 0],
#        [0, 3]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.random.random()
# Out:
# 0.6633010738963776

# %%
np.random.random((2,3))
# Out:
# array([[0.39463625, 0.31476296, 0.95677686],
#        [0.45607749, 0.38866446, 0.22059243]])

# %%
np.random.randn(2,3)
# Out:
# array([[-0.30560285, -1.21395284,  0.62055025],
#        [ 0.36435747,  0.52324073,  0.02521701]])

# %%
R = np.random.randn(10000)

# %%
R.mean()
# Out:
# -0.00034974218557215264

# %%
np.mean(R)
# Out:
# -0.00034974218557215264

# %%
R.var()
# Out:
# 1.0079022428811235

# %%
R.std()
# Out:
# 1.0039433464499496

# %%
Q = np.random.randn(1000,3)

# %%
Q.mean(axis=0)
# Out:
# array([ 0.03025278,  0.01095031, -0.00069526])

# %%
Q.mean(axis=1)
# Out:
# array([-2.16965785e-01,  6.62408469e-01, -7.62931796e-01,  5.02202023e-01,
#        -1.41891346e-01, -2.88069355e-01,  9.53672294e-02, -1.57768219e-01,
#         4.56803360e-01,  1.30816337e-01,  4.42332253e-01,  1.09711222e-01,
#         4.65756982e-01, -7.92028908e-01,  6.78509612e-01, -2.59725891e-01,
#         2.95537151e-01, -1.09453504e+00, -1.68312659e-02, -4.79722013e-01,
#        -8.45483682e-03,  6.45395703e-01, -8.78988076e-01,  1.69400956e-01,
#         5.70851098e-01,  3.11524359e-01,  1.94832139e-01, -4.59768064e-01,
#        -1.03028172e-01, -2.97500122e-01, -4.15986919e-01,  7.45864232e-01,
#        -5.62229848e-01,  5.05012558e-01,  2.27281179e-01, -1.14705736e+00,
#         4.41124931e-02,  1.42282070e-01, -9.59078084e-02,  3.28423593e-01,
#        -1.16000550e-01, -3.48264914e-01,  1.40118698e-01,  5.64267601e-01,
#        -8.86609730e-01,  1.01915124e+00,  7.60052894e-01, -4.44186249e-01,
# ...

# %%
Q.mean(axis=1).shape
# Out:
# (1000,)

# %%
np.cov(Q)
# Out:
# array([[ 0.53543062,  0.06362931,  0.79657425, ..., -0.48768223,
#          0.54586095, -0.21242569],
#        [ 0.06362931,  0.11359488, -0.07971442, ...,  0.15410683,
#         -0.05620985,  0.11363663],
#        [ 0.79657425, -0.07971442,  1.47185746, ..., -1.07428466,
#          1.01121204, -0.54442814],
#        ...,
#        [-0.48768223,  0.15410683, -1.07428466, ...,  0.86830598,
#         -0.73933427,  0.47123738],
#        [ 0.54586095, -0.05620985,  1.01121204, ..., -0.73933427,
#          0.69475332, -0.37515076],
#        [-0.21242569,  0.11363663, -0.54442814, ...,  0.47123738,
#         -0.37515076,  0.26618125]])

# %%
np.cov(Q.T)
# Out:
# array([[1.00638082, 0.01596361, 0.02345923],
#        [0.01596361, 0.96877441, 0.01418802],
#        [0.02345923, 0.01418802, 0.95058839]])
