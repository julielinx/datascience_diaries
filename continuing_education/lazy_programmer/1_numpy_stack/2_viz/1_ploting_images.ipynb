# %%
# !pip install wget
# !pip install pillow

# %%
import wget
import numpy as np
import matplotlib.pyplot as plt

# %%
wget.download('https://github.com/julielinx/datascience_diaries/blob/master/img/HOML_gradient_descent.png?raw=true')
# Out:
# 'HOML_gradient_descent.png'

# %%
from PIL import Image

# %%
im = Image.open('HOML_gradient_descent.png')

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
arr = np.array(im)

# %%
arr
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
plt.imshow(arr);

# %%
plt.imshow(im);

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray);

# %%
plt.imshow(gray, cmap='gray');
